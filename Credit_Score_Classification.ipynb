# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_seq_items', None)

# %%
data = pd.read_csv('data/credit_score_train.csv')
data.head(1)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
#
#                                                           Type_of_Loan  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
#
#    Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                  3.0                     7.0                 11.27
#
#    Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                   4.0       Good            809.98
#
#    Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 0                  26.82262               265.0                    No
#
#    Total_EMI_per_month  Amount_invested_monthly  \
# ...

# %%
score_mapping = {'Poor': 1, 'Standard': 2, 'Good': 3}
data['Numeric_Score'] = data['Credit_Score'].map(score_mapping)
data.head(3)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
# 1            3.0          4.0
# 2            3.0          4.0
#
#                                                           Type_of_Loan  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
# 1  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
# ...

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x='Occupation', y='Numeric_Score', hue='Credit_Score', data=data, errorbar=None, palette={'Poor': 'red', 'Standard': 'yellow', 'Good': 'green'})

plt.title('Average Credit Scores Based on Occupation')
plt.xlabel('Occupation')
plt.ylabel('Average Credit Score')
plt.xticks(rotation=45)
plt.yticks(ticks=[1, 2, 3], labels=['Poor', 'Standard', 'Good'])  # Setting y-ticks labels to credit scores
plt.legend(title='Credit Score')

plt.show()

# %%
import matplotlib.patches as mpatches

plt.figure(figsize=(12, 8))
sns.boxplot(x='Credit_Score', y='Annual_Income', data=data, hue='Credit_Score', dodge=False, palette={'Poor': 'red', 'Standard': 'yellow', 'Good': 'green'})

# Customize the plot
plt.title('Credit Scores Based on Annual Income')
plt.xlabel('Credit Score')
plt.ylabel('Annual Income')

legend_labels = [mpatches.Patch(color=color, label=score) for score, color in {'Poor': 'red', 'Standard': 'yellow', 'Good': 'green'}.items()]
plt.legend(handles=legend_labels, title='Credit Score', loc='upper left')

# Show the plot
plt.show()
