# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# Optional imports
from matplotlib import rcParams
from matplotlib import font_manager

# %% [markdown]
# ## Settings

# %%
for font in font_manager.findSystemFonts(fontpaths=None, fontext='ttf'):
    font_manager.fontManager.addfont(font)

# %%
rcParams.update(
    {
        "font.family": "Arial",
        "figure.figsize": (20, 9),
        "figure.facecolor": "#fbfbfb",
        "figure.titlesize": 40,
        "figure.titleweight": "bold",
        "font.size": 25,
        "lines.linewidth": 3,
        "grid.linewidth": 1.25,
        "grid.color": "#f6f5f4",
        "xtick.bottom": False,
        "ytick.left": False,
        "axes.spines.right": False,
        "axes.spines.top": False,
        "axes.edgecolor": "#c0bfbc"  # spine colour
    }
)

# %% [markdown]
# ## Plot template

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("The TITLE")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here
# ...

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()

# %% [markdown]
# ## Axes lines

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("Example A")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here

# Example A
for i in range(3):
    axs[i].set_title("A")
    axs[i].axhline(
      y=np.random.randint(1, 10)  # data coordinates
    )

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("Example B")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here

# Example B
for i in range(3):

    axs[i].set_title("B")
    axs[i].axhline(
        y=np.random.randint(1, 10),  # data coordinates
        xmax=.5  # axe coordinates [0, 1]
    )
    axs[i].axhline(
        y=np.random.randint(1, 10),  # data coordinates
        xmin=.5  # axe coordinates [0, 1]
    )

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("Example C")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here

# Example C
for i in range(3):

    axs[i].set_title("C")
    axs[i].axhline(
        y=np.random.randint(1, 10),
        xmin=.2,  # axe coordinates [0, 1]
        xmax=.8  # axe coordinates [0, 1]
    )
    axs[i].axhline(
        y=np.random.randint(1, 10),
        xmin=.3,  # axe coordinates [0, 1]
        xmax=.7  # axe coordinates [0, 1]
    )
    axs[i].axhline(
        y=np.random.randint(1, 10),
        xmin=.4,  # axe coordinates [0, 1]
        xmax=.6  # axe coordinates [0, 1]

)

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("Example D")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here

# Example D
for i in range(3):
    axs[i].set_title("D")
    axs[i].axvline(
        x=np.random.randint(1, 10)
    )

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("Example E")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here

# Example E
for i in range(3):

    axs[i].set_title("E")
    axs[i].axvline(
        x=np.random.randint(1, 10),  # data coordinates
        ymax=.5,  # axe coordinates [0, 1]
        color='purple'
    )
    axs[i].axvline(
        x=np.random.randint(1, 10),  # data coordinates
        ymin=.5,  # axe coordinates [0, 1]
        color='greenyellow'
    )

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()

# %%
fig, axs = plt.subplots(
    1, 3,
    sharex=True,
    sharey=True,
    layout="constrained"
)
fig.suptitle("Example F")

# Axis limits
axs[0].set_xlim(0, 10)
axs[0].set_ylim(0, 10)

# PLOTS

# Plot functions go here

# Example F
for i in range(3):

    axs[i].set_title("F")
    axs[i].axvline(
        x=1,  # data coordinates
        ymin=.2,  # axe coordinates [0, 1]
        ymax=.8,  # axe coordinates [0, 1]
        color='tomato'
    )
    axs[i].axvline(
        x=5,  # data coordinates
        ymin=.3,  # axe coordinates [0, 1]
        ymax=.7,  # axe coordinates [0, 1]
        color='royalblue'
    )
    axs[i].axvline(
        x=9,  # data coordinates
        ymin=.4,  # axe coordinates [0, 1]
        ymax=.6,  # axe coordinates [0, 1]
        color='gold'
    )

# Other settings
for ax in axs:
    ax.set_xticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{x}" for x in np.arange(2, 10, 2)] + [""],
    )
    ax.set_yticks(
        ticks=np.arange(2, 11, 2),
        labels=[f"{y}" for y in np.arange(2, 10, 2)] + [""],
    )
    ax.grid()

plt.show()
