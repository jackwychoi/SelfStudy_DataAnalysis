# %%
from typing import Tuple, List, Dict

import pandas as pd
import folium

pd.set_option('display.precision', 2)


df_sites = pd.DataFrame(
    [['hotel',              48.8527, 2.3542],
     ['Sacre Coeur',        48.8867, 2.3431],
     ['Louvre',             48.8607, 2.3376],
     ['Montmartre',         48.8872, 2.3388],
     ['Port de Suffren',    48.8577, 2.2902],
     ['Arc de Triomphe',    48.8739, 2.2950],
     ['Av. Champs Élysées', 48.8710, 2.3036],
     ['Notre Dame',         48.8531, 2.3498],
     ['Tour Eiffel',        48.8585, 2.2945]],
    columns=pd.Index(['site', 'latitude', 'longitude'], name='paris')
)

df_sites
# Out:
# paris                site  latitude  longitude
# 0                   hotel     48.85       2.35
# 1             Sacre Coeur     48.89       2.34
# 2                  Louvre     48.86       2.34
# 3              Montmartre     48.89       2.34
# 4         Port de Suffren     48.86       2.29
# 5         Arc de Triomphe     48.87       2.29
# 6      Av. Champs Élysées     48.87       2.30
# 7              Notre Dame     48.85       2.35
# 8             Tour Eiffel     48.86       2.29

# %%
avg_location = df_sites[['latitude', 'longitude']].mean()
map_paris = folium.Map(location=avg_location, zoom_start=13)

# %%
for site in df_sites.itertuples():
    marker = folium.Marker(location=(site.latitude, site.longitude),
                           tooltip=site.site)
    marker.add_to(map_paris)

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49a0efbf87d64577aa0708702cb446fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49a0efbf87d64577aa0708702cb446fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49a0efbf87d64577aa0708702cb446fc = L.map(
#                 &quot;map_49a0efbf87d64577aa0708702cb446fc&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4e1f0fc6aab63969181206a6e01f5ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             var marker_01643970f06420a38b712a23391ef0db = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_01643970f06420a38b712a23391ef0db.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5c87b66eddfd4c6ce9d16f0b27a9ecee = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_5c87b66eddfd4c6ce9d16f0b27a9ecee.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ea1e0f6e1dbb9da05b5285dc12e3a832 = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_ea1e0f6e1dbb9da05b5285dc12e3a832.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3f3d0ec7906d0c5ebb4e2ccb6e16fd90 = L.marker(
#                 [48.8872, 2.3388],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_3f3d0ec7906d0c5ebb4e2ccb6e16fd90.bindTooltip(
#                 `&lt;div&gt;
#                      Montmartre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0d715cef9bd4352d3f77a27b28e4296 = L.marker(
#                 [48.8577, 2.2902],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_b0d715cef9bd4352d3f77a27b28e4296.bindTooltip(
#                 `&lt;div&gt;
#                      Port de Suffren
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_74339b370dc76bea64ef06b2dd603f7b = L.marker(
#                 [48.8739, 2.295],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_74339b370dc76bea64ef06b2dd603f7b.bindTooltip(
#                 `&lt;div&gt;
#                      Arc de Triomphe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b1be4b54a58a9be80691ad542ca4033c = L.marker(
#                 [48.871, 2.3036],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_b1be4b54a58a9be80691ad542ca4033c.bindTooltip(
#                 `&lt;div&gt;
#                      Av. Champs Élysées
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d1c56b1efb03f17040ecd09abab4fd83 = L.marker(
#                 [48.8531, 2.3498],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_d1c56b1efb03f17040ecd09abab4fd83.bindTooltip(
#                 `&lt;div&gt;
#                      Notre Dame
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_df753fcd14ea7de5867220eec252368e = L.marker(
#                 [48.8585, 2.2945],
#                 {}
#             ).addTo(map_49a0efbf87d64577aa0708702cb446fc);
#
#
#             marker_df753fcd14ea7de5867220eec252368e.bindTooltip(
#                 `&lt;div&gt;
#                      Tour Eiffel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_route = df_sites.copy()
df_route.index.name = 'visit_order'

df_route
# Out:
# paris                      site  latitude  longitude
# visit_order
# 0                         hotel     48.85       2.35
# 1                   Sacre Coeur     48.89       2.34
# 2                        Louvre     48.86       2.34
# 3                    Montmartre     48.89       2.34
# 4               Port de Suffren     48.86       2.29
# 5               Arc de Triomphe     48.87       2.29
# 6            Av. Champs Élysées     48.87       2.30
# 7                    Notre Dame     48.85       2.35
# 8                   Tour Eiffel     48.86       2.29

# %%
df_route_segments = df_route.join(
    df_route.shift(-1),  # map each stop to its next stop
    rsuffix='_next'
).dropna()  # last stop has no "next one", so drop it

df_route_segments
# Out:
# paris                      site  latitude  longitude           site_next  \
# visit_order
# 0                         hotel     48.85       2.35         Sacre Coeur
# 1                   Sacre Coeur     48.89       2.34              Louvre
# 2                        Louvre     48.86       2.34          Montmartre
# 3                    Montmartre     48.89       2.34     Port de Suffren
# 4               Port de Suffren     48.86       2.29     Arc de Triomphe
# 5               Arc de Triomphe     48.87       2.29  Av. Champs Élysées
# 6            Av. Champs Élysées     48.87       2.30          Notre Dame
# 7                    Notre Dame     48.85       2.35         Tour Eiffel
#
# paris        latitude_next  longitude_next
# visit_order
# 0                    48.89            2.34
# 1                    48.86            2.34
# 2                    48.89            2.34
# 3                    48.86            2.29
# 4                    48.87            2.29
# 5                    48.87            2.30
# 6                    48.85            2.35
# 7                    48.86            2.29

# %%
map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           tooltip=stop.site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude), 
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.site} to {stop.site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# maker for last stop wasn't added in for loop, so adding it now 
folium.Marker(location=(stop.latitude_next, stop.longitude_next),
              tooltip=stop.site_next).add_to(map_paris);

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d03525aff1e03052e91da9c9996d4a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d03525aff1e03052e91da9c9996d4a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d03525aff1e03052e91da9c9996d4a7 = L.map(
#                 &quot;map_7d03525aff1e03052e91da9c9996d4a7&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2248240bddbb3b05acfef63b34c7f775 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             var marker_89fb13e883a1208bac850b7e4968e944 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             marker_89fb13e883a1208bac850b7e4968e944.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_99f230ae69d9d4cb546cecc54b9a1a71 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             poly_line_99f230ae69d9d4cb546cecc54b9a1a71.bindTooltip(
#                 `&lt;div&gt;
#                      hotel to Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7d130c6cf37b98bc2a2ba7ea8c0c24dc = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             marker_7d130c6cf37b98bc2a2ba7ea8c0c24dc.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_cb4ed368e1a75ad3d3659597af26b647 = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             poly_line_cb4ed368e1a75ad3d3659597af26b647.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur to Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1cc625d4c803bb2fe84cf58b9f120490 = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             marker_1cc625d4c803bb2fe84cf58b9f120490.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_4caa5d5083a9fb18257dacae18d4bd8f = L.polyline(
#                 [[48.8607, 2.3376], [48.8872, 2.3388]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d03525aff1e03052e91da9c9996d4a7);
#
#
#             poly_line_4caa5d5083a9fb18257dacae18d4bd8f.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre to Montmartre
#                  &lt;/div&gt;`,

# %%
map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    initial_stop = stop.Index == 0
    # icon for current stop
    icon = folium.Icon(icon='home' if initial_stop else 'info-sign', 
                       color='cadetblue' if initial_stop else 'red')
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           icon=icon, tooltip=stop.site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude), 
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.site} to {stop.site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# When for loop ends, the stop variable has the second-to-last 
# stop in the route, so the marker for the last stop is missing 
# We add it now using the "next" columns of the last row
folium.Marker(
    location=(stop.latitude_next, stop.longitude_next),
    tooltip=stop.site_next, 
    icon = folium.Icon(icon='info-sign', color='red')
).add_to(map_paris);

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a743d5a2c5d6f5c348d0562242ff9d02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a743d5a2c5d6f5c348d0562242ff9d02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a743d5a2c5d6f5c348d0562242ff9d02 = L.map(
#                 &quot;map_a743d5a2c5d6f5c348d0562242ff9d02&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60c0ad4c088829b09f81f9b7e3e05ffe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a743d5a2c5d6f5c348d0562242ff9d02);
#
#
#             var marker_db499707d2eec385290df9f6e8ada0b5 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_a743d5a2c5d6f5c348d0562242ff9d02);
#
#
#             var icon_6d51bcc672e1a79dc1426f1696441edd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db499707d2eec385290df9f6e8ada0b5.setIcon(icon_6d51bcc672e1a79dc1426f1696441edd);
#
#
#             marker_db499707d2eec385290df9f6e8ada0b5.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_a85511866e9ee401b16534402162ebfe = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a743d5a2c5d6f5c348d0562242ff9d02);
#
#
#             poly_line_a85511866e9ee401b16534402162ebfe.bindTooltip(
#                 `&lt;div&gt;
#                      hotel to Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f547dfbb47eab535e2361b900af33c4 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_a743d5a2c5d6f5c348d0562242ff9d02);
#
#
#             var icon_e77313c3750cc010586d274c8eb6cca7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f547dfbb47eab535e2361b900af33c4.setIcon(icon_e77313c3750cc010586d274c8eb6cca7);
#
#
#             marker_7f547dfbb47eab535e2361b900af33c4.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_bff987fb373444731a13c07f12989a2b = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a743d5a2c5d6f5c348d0562242ff9d02);
#
#
#             poly_line_bff987fb373444731a13c07f12989a2b.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur to Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6bb7eddda7d3228f5cfed243669fe53b = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_a743d5a2c5d6f5c348d0562242ff9d02);
#
#
#             var icon_680b5318880a28b46c2daddaf89077ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&q

# %%
from geopy.distance import geodesic

_Location = Tuple[float, float]


def ellipsoidal_distance(point1: _Location, point2: _Location) -> float:
    """Calculate ellipsoidal distance (in meters) between point1 and 
    point2 where each point is represented as a tuple (lat, lon)"""
    return geodesic(point1, point2).meters

# %%
df_route_segments['distance_seg'] = df_route_segments.apply(
    lambda stop: ellipsoidal_distance(
        (stop.latitude, stop.longitude), 
        (stop.latitude_next, stop.longitude_next)), 
    axis=1
)

df_route_segments
# Out:
# paris                      site  latitude  longitude           site_next  \
# visit_order
# 0                         hotel     48.85       2.35         Sacre Coeur
# 1                   Sacre Coeur     48.89       2.34              Louvre
# 2                        Louvre     48.86       2.34          Montmartre
# 3                    Montmartre     48.89       2.34     Port de Suffren
# 4               Port de Suffren     48.86       2.29     Arc de Triomphe
# 5               Arc de Triomphe     48.87       2.29  Av. Champs Élysées
# 6            Av. Champs Élysées     48.87       2.30          Notre Dame
# 7                    Notre Dame     48.85       2.35         Tour Eiffel
#
# paris        latitude_next  longitude_next  distance_seg
# visit_order
# 0                    48.89            2.34       3867.74
# 1                    48.86            2.34       2919.40
# 2                    48.89            2.34       2948.31
# 3                    48.86            2.29       4844.92
# 4                    48.87            2.29       1835.65
# 5                    48.87            2.30        708.53
# 6                    48.85            2.35       3931.12
# 7                    48.86            2.29       4102.26

# %%
map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    initial_stop = stop.Index == 0
    # marker for current stop
    icon = folium.Icon(icon='home' if initial_stop else 'info-sign', 
                       color='cadetblue' if initial_stop else 'red')
    marker = folium.Marker(
        location=(stop.latitude, stop.longitude),
        icon=icon, 
        # display the name and stop number at each site's marker
        tooltip=f"<b>Name</b>: {stop.site} <br>" \
              + f"<b>Stop number</b>: {stop.Index} <br>"
    )
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude), 
                   (stop.latitude_next, stop.longitude_next)],
        # display the start, end, and distance of each segment
        tooltip=f"<b>From</b>: {stop.site} <br>" \
              + f"<b>To</b>: {stop.site_next} <br>" \
              + f"<b>Distance</b>: {stop.distance_seg:.0f} m",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# add route's last marker, as it wasn't included in for loop
folium.Marker(
    location=(stop.latitude_next, stop.longitude_next),
    tooltip=f"<b>Name</b>: {stop.site_next} <br>" \
          + f"<b>Stop number</b>: {stop.Index + 1} <br>", 
    icon = folium.Icon(icon='info-sign', color='red')
).add_to(map_paris);

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57389186003751237b0334b8f66d8c1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57389186003751237b0334b8f66d8c1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57389186003751237b0334b8f66d8c1d = L.map(
#                 &quot;map_57389186003751237b0334b8f66d8c1d&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0885ec2d7d6568b355cf59b0c18a79e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57389186003751237b0334b8f66d8c1d);
#
#
#             var marker_610ba2f3d28741528c715cf4b6a78581 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_57389186003751237b0334b8f66d8c1d);
#
#
#             var icon_f22d5d4bbe04db2efafc9d32710d62ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_610ba2f3d28741528c715cf4b6a78581.setIcon(icon_f22d5d4bbe04db2efafc9d32710d62ff);
#
#
#             marker_610ba2f3d28741528c715cf4b6a78581.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 0 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_4b64a7d4727d30ced121a96f1c04f857 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_57389186003751237b0334b8f66d8c1d);
#
#
#             poly_line_4b64a7d4727d30ced121a96f1c04f857.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 3868 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_860faffaa7eefedefac93148717a9445 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_57389186003751237b0334b8f66d8c1d);
#
#
#             var icon_040cb503904feab35290568483868cb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_860faffaa7eefedefac93148717a9445.setIcon(icon_040cb503904feab35290568483868cb5);
#
#
#             marker_860faffaa7eefedefac93148717a9445.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 1 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_a866ef28b65e3498c46cec0a75d8f1d7 = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_57389186003751237b0334b8f66d8c1d);
#
#
#             poly_line_a866ef28b65e3498c46cec0a75d8f1d7.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Louvre &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 2919 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ba3bcaf6ea549a5a8a824bb93e979a9 =

# %%
def _make_route_segments_df(df_route: pd.DataFrame) -> pd.DataFrame:
    """Given a dataframe whose rows are ordered stops in a route, 
    and where the index has integers representing the visit order of those
    stops, return a dataframe having new columns with the information of 
    each stop's next site"""
    df_route_segments = df_route.join(
        df_route.shift(-1),  # map each stop to its next
        rsuffix='_next').dropna()

    df_route_segments['distance_seg'] = df_route_segments.apply(
        lambda stop: ellipsoidal_distance(
            (stop.latitude, stop.longitude), 
            (stop.latitude_next, stop.longitude_next)
        ), axis=1
    )
    return df_route_segments


def plot_route_on_map(df_route: pd.DataFrame) -> folium.Map:
    """Takes a dataframe of a route and displays it on a map, adding 
    a marker for each stop and a line for each pair of consecutive 
    stops"""
    df_route_segments = _make_route_segments_df(df_route)
    
    # create empty map
    avg_location = df_route[['latitude', 'longitude']].mean()
    map_route = folium.Map(location=avg_location, zoom_start=13)

    for stop in df_route_segments.itertuples():
        initial_stop = stop.Index == 0
        # marker for current stop
        icon = folium.Icon(icon='home' if initial_stop else 'info-sign', 
                           color='cadetblue' if initial_stop else 'red')
        marker = folium.Marker(
            location=(stop.latitude, stop.longitude),
            icon=icon, 
            tooltip=f"<b>Name</b>: {stop.site} <br>" \
                  + f"<b>Stop number</b>: {stop.Index} <br>"
        )
        # line for the route segment connecting current to next stop
        line = folium.PolyLine(
            locations=[(stop.latitude, stop.longitude), 
                       (stop.latitude_next, stop.longitude_next)],
            # add to each line its start, end, and distance
            tooltip=f"<b>From</b>: {stop.site} <br>" \
                  + f"<b>To</b>: {stop.site_next} <br>" \
                  + f"<b>Distance</b>: {stop.distance_seg:.0f} m",
        )
        # add elements to the map
        marker.add_to(map_route)
        line.add_to(map_route)
    
    # When for loop ends, the stop variable has the second-to-last stop in 
    # the route, so the marker for the last stop is missing, and we add it 
    # now using the "next" columns of the last row
    folium.Marker(
        location=(stop.latitude_next, stop.longitude_next),
        tooltip=f"<b>Name</b>: {stop.site_next} <br>" \
              + f"<b>Stop number</b>: {stop.Index + 1} <br>", 
        icon = folium.Icon(icon='info-sign', color='red')
    ).add_to(map_route)
    
    return map_route

# %%
df_route_closed = pd.concat(
   [df_route, df_route.head(1)], ignore_index=True
)
df_route_closed.index.name = df_route.index.name

df_route_closed
# Out:
# paris                      site  latitude  longitude
# visit_order
# 0                         hotel     48.85       2.35
# 1                   Sacre Coeur     48.89       2.34
# 2                        Louvre     48.86       2.34
# 3                    Montmartre     48.89       2.34
# 4               Port de Suffren     48.86       2.29
# 5               Arc de Triomphe     48.87       2.29
# 6            Av. Champs Élysées     48.87       2.30
# 7                    Notre Dame     48.85       2.35
# 8                   Tour Eiffel     48.86       2.29
# 9                         hotel     48.85       2.35

# %%
plot_route_on_map(df_route_closed)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dd78541904ff27c098e280cf0ebbac0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dd78541904ff27c098e280cf0ebbac0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dd78541904ff27c098e280cf0ebbac0 = L.map(
#                 &quot;map_2dd78541904ff27c098e280cf0ebbac0&quot;,
#                 {
#                     center: [48.86541999999999, 2.3260999999999994],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b8e539a8553236d5124b69a950f97a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2dd78541904ff27c098e280cf0ebbac0);
#
#
#             var marker_43c6a5798c2e6b9767d768741aadee4e = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_2dd78541904ff27c098e280cf0ebbac0);
#
#
#             var icon_96085a33c89d23a4014f56ea8d5779c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_43c6a5798c2e6b9767d768741aadee4e.setIcon(icon_96085a33c89d23a4014f56ea8d5779c6);
#
#
#             marker_43c6a5798c2e6b9767d768741aadee4e.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 0 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_429e942be0c8edd0ec8815fdd4e88fc7 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2dd78541904ff27c098e280cf0ebbac0);
#
#
#             poly_line_429e942be0c8edd0ec8815fdd4e88fc7.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 3868 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1251255a2078046b8abc20df393b4708 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_2dd78541904ff27c098e280cf0ebbac0);
#
#
#             var icon_e8177ee41fa5727b6b1c175f94c8f731 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1251255a2078046b8abc20df393b4708.setIcon(icon_e8177ee41fa5727b6b1c175f94c8f731);
#
#
#             marker_1251255a2078046b8abc20df393b4708.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 1 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_af3b5e9aace70b955a301c647f97308b = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2dd78541904ff27c098e280cf0ebbac0);
#
#
#             poly_line_af3b5e9aace70b955a301c647f97308b.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Louvre &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 2919 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f01ec43e34f1a9f0538d21cfc369c092 =
