# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
hibiya = pd.read_csv('data/gmonpro_20221207_085354_Sim1_44011.csv', header=None)

# %%
hibiya.head(3)
# Out:
#                                                    0
# 0  PLMN;SYSTEM;XCI;xNBID;LOCAL_CID;LAC/TAC;PCI/PS...
# 1  44011;4;71727112;280184;8;211;31;1575;1800 B3;...
# 2  44011;4;71727112;280184;8;211;31;1575;1800 B3;...

# %%
hibiya = hibiya[0].str.split(';', expand=True)
hibiya.columns = hibiya.iloc[0]
hibiya.drop(0, inplace=True)
hibiya.reset_index(drop=True, inplace=True)

# %%
hibiya.rename(columns={'PCI/PSC/BSIC':'PCI', 'RSRP/RSCP':'RSRP', 'RSRQ/ECIO':'RSRQ', 'SNR':'SINR', 'LAT':'LAT_org', 'LON':'LON_org', 'TIME':'TIME_org'}, inplace=True)
hibiya.insert(0, 'LON', hibiya['LON_org'])
hibiya.insert(0, 'LAT', hibiya['LAT_org'])
hibiya.insert(0, 'TIME', hibiya['TIME_org'])
hibiya.drop(['LON_org', 'LAT_org', 'TIME_org'], axis=1, inplace=True)

# %%
hibiya.head(3)
# Out:
# 0      TIME        LAT         LON   PLMN SYSTEM       XCI   xNBID LOCAL_CID  \
# 0  08:53:54  35.732882  139.795405  44011      4  71727112  280184         8
# 1  08:53:55  35.732882  139.795405  44011      4  71727112  280184         8
# 2  08:53:56  35.732882  139.795405  44011      4  71727112  280184         8
#
# 0 LAC/TAC PCI ARFCN     BAND RSSI RSRP RSRQ SINR CQI   TA DISTANCE DELTA_AZI  \
# 0     211  31  1575  1800 B3  -67  -86   -6  1.6      180
# 1     211  31  1575  1800 B3  -67  -86   -6  1.6      180
# 2     211  31  1575  1800 B3  -67  -84   -6  1.6      180
#
# 0 SPEED GPS_ACCURACY  UL    DL BANDWIDTH BANDWIDTHS CA NR_STATE NARFCN  \
# 0     0         1200  61  1227     20000         20  1     none
# 1     0         1200  46   953     20000         20  1     none
# 2     0         1200  56  1084     20000         20  1     none
#
# 0 NR_BAND NR_PCI NR_SS_RSRP NR_SS_RSRQ NR_SS_SINR NR_CSI_RSRP NR_CSI_RSRQ  \
# 0
# 1
# 2
#
# 0 NR_CSI_SINR CLF_LABEL CLF_LOC                             CLF_DESC  \
# 0                    --      --  Cell not found in the clf database!
# 1                    --      --  Cell not found in the clf database!
# 2                    --      --  Cell not found in the clf database!
#
# 0        DATE ROAMING
# 0  2022/12/07    HOME
# 1  2022/12/07    HOME
# 2  2022/12/07    HOME

# %%
hibiya.insert(0, 'STATION', None)

# %%
'''
08:54:46 Depart Minowa
08:55:53 Arrive Iriya
08:56:57 Depart Iriya
08:58:05 Arrive Ueno
08:59:17 Depart Ueno
09:00:04 Arrive Nakaokachimachi
09:01:17 Depart Nakaokachimachi
09:02:14 ArriveAkihabara
''';

# %%
print(hibiya.loc[hibiya['TIME']=='08:54:46'].index.values)
print(hibiya.loc[hibiya['TIME']=='08:55:53'].index.values)
print(hibiya.loc[hibiya['TIME']=='08:56:57'].index.values)
print(hibiya.loc[hibiya['TIME']=='08:58:05'].index.values)
print(hibiya.loc[hibiya['TIME']=='08:59:17'].index.values)
print(hibiya.loc[hibiya['TIME']=='09:00:04'].index.values)
print(hibiya.loc[hibiya['TIME']=='09:01:17'].index.values)
print(hibiya.loc[hibiya['TIME']=='09:02:14'].index.values)
# Out:
# [52]
# [119]
# [183]
# [251]
# [323]
# [370]
# [443]
# [499]

# %%
hibiya.loc[0:52,'STATION'] = '01. Minowa'
hibiya.loc[53:119,'STATION'] = '02. Minowa-Iriya Tunnel'
hibiya.loc[120:183,'STATION'] = '03. Iriya'
hibiya.loc[184:251,'STATION'] = '04. Iriya-Ueno Tunnel'
hibiya.loc[252:323,'STATION'] = '05. Ueno'
hibiya.loc[324:370,'STATION'] = '06. Ueno-Nakaokachimachi Tunnel'
hibiya.loc[371:443,'STATION'] = '07. Nakaokachimachi'
hibiya.loc[444:499,'STATION'] = '08. Nakaokachimachi-Akihabara Tunnel'
hibiya.loc[500:,'STATION'] = '09. Akihabara'

# %%
hibiya.head(3)
# Out:
# 0     STATION      TIME        LAT         LON   PLMN SYSTEM       XCI  \
# 0  01. Minowa  08:53:54  35.732882  139.795405  44011      4  71727112
# 1  01. Minowa  08:53:55  35.732882  139.795405  44011      4  71727112
# 2  01. Minowa  08:53:56  35.732882  139.795405  44011      4  71727112
#
# 0   xNBID LOCAL_CID LAC/TAC PCI ARFCN     BAND RSSI RSRP RSRQ SINR CQI   TA  \
# 0  280184         8     211  31  1575  1800 B3  -67  -86   -6  1.6      180
# 1  280184         8     211  31  1575  1800 B3  -67  -86   -6  1.6      180
# 2  280184         8     211  31  1575  1800 B3  -67  -84   -6  1.6      180
#
# 0 DISTANCE DELTA_AZI SPEED GPS_ACCURACY  UL    DL BANDWIDTH BANDWIDTHS CA  \
# 0                        0         1200  61  1227     20000         20  1
# 1                        0         1200  46   953     20000         20  1
# 2                        0         1200  56  1084     20000         20  1
#
# 0 NR_STATE NARFCN NR_BAND NR_PCI NR_SS_RSRP NR_SS_RSRQ NR_SS_SINR NR_CSI_RSRP  \
# 0     none
# 1     none
# 2     none
#
# 0 NR_CSI_RSRQ NR_CSI_SINR CLF_LABEL CLF_LOC  \
# 0                                --      --
# 1                                --      --
# 2                                --      --
#
# 0                             CLF_DESC        DATE ROAMING
# 0  Cell not found in the clf database!  2022/12/07    HOME
# 1  Cell not found in the clf database!  2022/12/07    HOME
# 2  Cell not found in the clf database!  2022/12/07    HOME

# %%
hibiya.tail(3)
# Out:
# 0          STATION      TIME        LAT         LON   PLMN SYSTEM       XCI  \
# 517  09. Akihabara  09:02:32  35.698174  139.775543  44011      4  71644420
# 518  09. Akihabara  09:02:33  35.698174  139.775543  44011      4  71644420
# 519  09. Akihabara  09:02:34  35.698174  139.775543  44011      4  71644420
#
# 0     xNBID LOCAL_CID LAC/TAC  PCI ARFCN     BAND RSSI  RSRP RSRQ SINR CQI  \
# 517  279861         4     211  351  1575  1800 B3  -89  -105   -6  0.5
# 518  279861         4     211  351  1575  1800 B3  -89  -105   -6  0.5
# 519  279861         4     211  351  1575  1800 B3  -89  -105   -6  0.5
#
# 0     TA DISTANCE DELTA_AZI SPEED GPS_ACCURACY  UL  DL BANDWIDTH BANDWIDTHS  \
# 517  173                       14           37  18  17     20000         20
# 518  173                       14           37   0   0     20000         20
# 519  173                       14           37   0   0     20000         20
#
# 0   CA NR_STATE NARFCN NR_BAND NR_PCI NR_SS_RSRP NR_SS_RSRQ NR_SS_SINR  \
# 517  1     none
# 518  1     none
# 519  1     none
#
# 0   NR_CSI_RSRP NR_CSI_RSRQ NR_CSI_SINR CLF_LABEL CLF_LOC  \
# 517                                            --      --
# 518                                            --      --
# 519                                            --      --
#
# 0                               CLF_DESC        DATE ROAMING
# 517  Cell not found in the clf database!  2022/12/07    HOME
# 518  Cell not found in the clf database!  2022/12/07    HOME
# 519  Cell not found in the clf database!  2022/12/07    HOME

# %%
print(hibiya['BAND'].unique())
# Out:
# ['1800 B3']

# %%
hibiya_band_mask = hibiya['BAND'].str.split(' ', expand=True)
hibiya['BAND'] = hibiya_band_mask[1]

# %%
cols = ['PCI', 'ARFCN', 'BAND', 'RSSI', 'RSRP', 'RSRQ', 'SINR', 'CQI', 'TA']
for i in cols:
    hibiya[i] = pd.to_numeric(hibiya[i], errors='coerce')

# %%
hibiya.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 43 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   STATION       520 non-null    object
#  1   TIME          520 non-null    object
#  2   LAT           520 non-null    object
#  3   LON           520 non-null    object
#  4   PLMN          520 non-null    object
#  5   SYSTEM        520 non-null    object
#  6   XCI           520 non-null    object
#  7   xNBID         520 non-null    object
#  8   LOCAL_CID     520 non-null    object
#  9   LAC/TAC       520 non-null    object
#  10  PCI           520 non-null    int64
#  11  ARFCN         520 non-null    int64
#  12  BAND          0 non-null      float64
#  13  RSSI          520 non-null    int64
#  14  RSRP          520 non-null    int64
#  15  RSRQ          520 non-null    int64
#  16  SINR          520 non-null    float64
#  17  CQI           0 non-null      float64
#  18  TA            512 non-null    float64
#  19  DISTANCE      520 non-null    object
#  20  DELTA_AZI     520 non-null    object
#  21  SPEED         520 non-null    object
#  22  GPS_ACCURACY  520 non-null    object
#  23  UL            520 non-null    object
#  24  DL            520 non-null    object
#  25  BANDWIDTH     520 non-null    object
#  26  BANDWIDTHS    520 non-null    object
#  27  CA            520 non-null    object
#  28  NR_STATE      520 non-null    object
#  29  NARFCN        520 non-null    object
#  30  NR_BAND       520 non-null    object
#  31  NR_PCI        520 non-null    object
#  32  NR_SS_RSRP    520 non-null    object
#  33  NR_SS_RSRQ    520 non-null    object
#  34  NR_SS_SINR    520 non-null    object
#  35  NR_CSI_RSRP   520 non-null    object
#  36  NR_CSI_RSRQ   520 non-null    object
#  37  NR_CSI_SINR   520 non-null    object
#  38  CLF_LABEL     520 non-null    object
#  39  CLF_LOC       520 non-null    object
#  40  CLF_DESC      520 non-null    object
#  41  DATE          520 non-null    object
#  42  ROAMING       520 non-null    object
# dtypes: float64(4), int64(5), object(34)
# memory usage: 174.8+ KB

# %%
def ctgrzrsrp(dfname, columnname):
    a = (-75 <= dfname[columnname])
    b = (dfname[columnname] < -125)
    dfname['Sort_'+columnname] = None
    dfname.loc[a, 'Sort_'+columnname] = '-75 <= rp'
    dfname.loc[b, 'Sort_'+columnname] = 'rp < -125'
    
    for i in range(-75, -125, -5):
        locals()['Var_{}'.format(i)] = (i-5 <= dfname[columnname]) & (dfname[columnname] < i) 
        dfname.loc[locals()['Var_{}'.format(i)], 'Sort_'+columnname] = str(i-5)+' <= rp < '+str(i)

# %%
ctgrzrsrp(hibiya, 'RSRP')

# %%
hibiya['Sort_RSRP'].unique()
# Out:
# array(['-90 <= rp < -85', '-85 <= rp < -80', '-95 <= rp < -90',
#        '-105 <= rp < -100', '-100 <= rp < -95', '-80 <= rp < -75',
#        '-110 <= rp < -105', '-115 <= rp < -110', '-120 <= rp < -115',
#        'rp < -125', '-125 <= rp < -120'], dtype=object)

# %%
hibiya['Sort_RSRP'].replace({'-75 <= rp':'A: -75 <= rp', '-80 <= rp < -75':'B: -80 <= rp < -75',
                             '-85 <= rp < -80':'C: -85 <= rp < -80', '-90 <= rp < -85':'D: -90 <= rp < -85',
                             '-95 <= rp < -90':'E: -95 <= rp < -90', '-100 <= rp < -95':'F: -100 <= rp < -95',
                             '-105 <= rp < -100':'G: -105 <= rp < -100', '-110 <= rp < -105':'H: -110 <= rp < -105', 
                             '-115 <= rp < -110':'I: -115 <= rp < -110', '-120 <= rp < -115':'J: -120 <= rp < -115',
                             '-125 <= rp < -120':'K: -125 <= rp < -120', 'rp < -125':'L: rp < -125'}, inplace=True)

# %%
# hibiya_bar = hibiya['Sort_RSRP'].value_counts(normalize=True).mul(100).round(2).sort_index(ascending=True).reset_index().T

# %%
'''hibiya_bar.columns = hibiya_bar.iloc[0]
hibiya_bar.drop('index', inplace=True)
hibiya_bar = hibiya_bar.rename_axis(columns={'index':None})''';

# %%
hibiya_bar = hibiya.groupby(['STATION'])['Sort_RSRP'].value_counts(normalize=True).mul(100).round(2).unstack().reset_index()

# %%
hibiya_bar
# Out:
# Sort_RSRP                               STATION  B: -80 <= rp < -75  \
# 0                                    01. Minowa                 NaN
# 1                       02. Minowa-Iriya Tunnel               10.45
# 2                                     03. Iriya                 NaN
# 3                         04. Iriya-Ueno Tunnel                2.94
# 4                                      05. Ueno                 NaN
# 5               06. Ueno-Nakaokachimachi Tunnel               10.64
# 6                           07. Nakaokachimachi                 NaN
# 7          08. Nakaokachimachi-Akihabara Tunnel                8.93
# 8                                 09. Akihabara                 NaN
#
# Sort_RSRP  C: -85 <= rp < -80  D: -90 <= rp < -85  E: -95 <= rp < -90  \
# 0                        7.55               26.42               43.40
# 1                       34.33               29.85               22.39
# 2                         NaN                4.69               25.00
# 3                       19.12               13.24               27.94
# 4                         NaN                9.72               26.39
# 5                        4.26               27.66               27.66
# 6                         NaN                 NaN                5.48
# 7                       26.79               30.36               21.43
# 8                         NaN                 NaN               15.00
#
# Sort_RSRP  F: -100 <= rp < -95  G: -105 <= rp < -100  H: -110 <= rp < -105  \
# 0                         9.43                 13.21                   NaN
# 1                          NaN                  2.99                   NaN
# 2                        17.19                 17.19                 35.94
# 3                        20.59                  5.88                 10.29
# 4                        27.78                 29.17                  6.94
# 5                        17.02                  8.51                  4.26
# 6                        38.36                 45.21                  6.85
# 7                        10.71                  1.79                   NaN
# 8                        10.00                 35.00                   NaN
#
# Sort_RSRP  I: -115 <= rp < -110  J: -120 <= rp < -115  K: -125 <= rp < -120  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                           NaN                   NaN                   NaN
# 3                           NaN                   NaN                   NaN
# 4                           NaN                   NaN                   NaN
# 5                           NaN                   NaN                   NaN
# 6                          4.11                   NaN                   NaN
# 7                           NaN                   NaN                   NaN
# 8                           NaN                  15.0                  10.0
#
# Sort_RSRP  L: rp < -125
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                  15.0

# %%
from matplotlib.ticker import FuncFormatter
plt.close()
plt.style.use('default')
sns.set(style='whitegrid', rc={'figure.figsize':(20, 10)})
ax = hibiya_bar.plot(  
     kind = 'bar', 
     stacked = True, 
     title = '', 
     mark_right = True, 
     color =['#003300', '#006600', '#33CC33', '#00FF00', '#99FF66', '#CCFFCC', '#FFFF00', '#FF9900', '#C02000', '#800000', '#000000'],
     width = 0.7,
     edgecolor = 'white',
     linewidth=0.5 
) 
#'#0000FF', '#003300', '#006600', '#33CC33', '#00FF00', '#99FF66', '#CCFFCC', '#FFFF00', '#FF9900', '#C02000', '#800000', '#000000'
labels = ['01. Minowa', '02. Minowa-Iriya Tunnel', '03. Iriya', 
          '04. Iriya-Ueno Tunnel', '05. Ueno', '06. Ueno-Nakaokachimachi Tunnel',
          '07. Nakaokachimachi', '08. Nakaokachimachi-Akihabara Tunnel', '09. Akihabara']

plt.legend(prop={"family":"Yu Gothic","size":12}, bbox_to_anchor=(1.005, 1.004), loc=2, borderaxespad=0.)

putwhiteblocks = hibiya_bar.loc[:,['B: -80 <= rp < -75', 'C: -85 <= rp < -80', 'K: -125 <= rp < -120', 'L: rp < -125']]

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    if height<1: continue
    if np.isin(height, putwhiteblocks):
        ax.annotate("{0:.2f}%".format(height), xy=(left + width / 2, bottom + height / 2), ha='center', va='center',
                    color="white", fontsize=12)
    else:
        ax.annotate("{0:.2f}%".format(height), xy=(left + width / 2, bottom + height / 2), ha='center', va='center', 
                    color='black', fontsize=12)

#ax.set_facecolor('#D9D9D9')
#plt.xlabel('RSRP Distribution')
ax.set_title('RSRP Distribution', fontsize=15, fontweight='bold')
#ax.axes.xaxis.set_visible(False)
plt.xticks(color='black', weight='bold', rotation=10)
plt.yticks(color='k', weight='bold')
#ax.suptitle('RSRP vs RSRQ', fontsize=20, fontweight='bold')
#ax.text(0.0, -4, 'RSRP', ha='center', va='center', fontsize=13)
#ax.text(0.02, 0.5, 'RSRQ (dB)', ha='center', va='center', rotation='vertical', fontsize=17, fontweight='bold')
ax.set_xticklabels(labels)
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}%'.format(y)))
plt.show()

# %%
from matplotlib.ticker import FuncFormatter
plt.close()
plt.style.use('default')
sns.set(style='whitegrid', rc={'figure.figsize':(20, 10)})
ax = hibiya_bar.plot(  
     kind = 'bar', 
     stacked = True, 
     title = '', 
     mark_right = True, 
     color =['#003300', '#006600', '#33CC33', '#00FF00', '#99FF66', '#CCFFCC', '#FFFF00', '#FF9900', '#C02000', '#800000', '#000000'],
     width = 0.7,
     edgecolor = 'white',
     linewidth=0.5 
) 
#'#0000FF', '#003300', '#006600', '#33CC33', '#00FF00', '#99FF66', '#CCFFCC', '#FFFF00', '#FF9900', '#C02000', '#800000', '#000000'
labels = ['01. Minowa', '02. Minowa-Iriya Tunnel', '03. Iriya', 
          '04. Iriya-Ueno Tunnel', '05. Ueno', '06. Ueno-Nakaokachimachi Tunnel',
          '07. Nakaokachimachi', '08. Nakaokachimachi-Akihabara Tunnel', '09. Akihabara']

plt.legend(prop={"family":"Yu Gothic","size":12}, bbox_to_anchor=(1.005, 1.004), loc=2, borderaxespad=0.)

for i in range(9):
    left, bottom, width, height = ax.patches[i].get_bbox().bounds
    if height<1: continue
    ax.annotate("{0:.2f}%".format(height), xy=(left + width / 2, bottom + height / 2), ha='center', va='center',
                    color="white", fontsize=12)
        
for i in range(9, 18):
    left, bottom, width, height = ax.patches[i].get_bbox().bounds
    if height<1: continue
    if np.isin(height, putwhiteblocks):
        ax.annotate("{0:.2f}%".format(height), xy=(left + width / 2, bottom + height / 2), ha='center', va='center',
                    color="white", fontsize=12)
        
for i in range(18, 81):
    left, bottom, width, height = ax.patches[i].get_bbox().bounds
    if height<1: continue
    ax.annotate("{0:.2f}%".format(height), xy=(left + width / 2, bottom + height / 2), ha='center', va='center',
                color="black", fontsize=12)
    
for i in range(81, 99):
    left, bottom, width, height = ax.patches[i].get_bbox().bounds
    if height<1: continue
    ax.annotate("{0:.2f}%".format(height), xy=(left + width / 2, bottom + height / 2), ha='center', va='center',
                color="white", fontsize=12)
    
ax.set_facecolor('lightblue')
#plt.xlabel('RSRP Distribution')
ax.set_title('RSRP Distribution', fontsize=15, fontweight='bold')
#ax.axes.xaxis.set_visible(False)
plt.xticks(color='black', weight='bold', rotation=10)
plt.yticks(color='k', weight='bold')
#ax.suptitle('RSRP vs RSRQ', fontsize=20, fontweight='bold')
#ax.text(0.0, -4, 'RSRP', ha='center', va='center', fontsize=13)
#ax.text(0.02, 0.5, 'RSRQ (dB)', ha='center', va='center', rotation='vertical', fontsize=17, fontweight='bold')
ax.set_xticklabels(labels)
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}%'.format(y)))
plt.show()

# %%
#plt.style.use('ggplot')
sns.set_style('darkgrid')
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
sns.scatterplot(data=hibiya, x='RSRP', y='RSRQ', color = 'royalblue', s=50)
ax.set(xlabel='', ylabel='')
fig.suptitle('RSRP vs RSRQ', fontname="Arial", fontsize=20, fontweight='bold')
fig.text(0.5, 0.02, 'RSRP (dBm)', ha='center', va='center', fontname="Arial", fontsize=17, fontweight='bold')
fig.text(0.06, 0.5, 'RSRQ (dB)', ha='center', va='center', fontname="Arial", rotation='vertical', fontsize=17, fontweight='bold')
#ax.yaxis.get_label().set_fontsize(15)
#ax.yaxis.label.set_color('#51585E')
ax.tick_params('x', labelrotation=50)
#ax.tick_params('y', labelrotation=50)
#ax.set_xticks(np.arange(-125, -55, step=5))
#ax.set_yticks(np.arange(-20, -4, step=2))
#ax.set_yticklabels(('', 50, 100, 150, 200, 250, 300), color='k', size=13)
#ax.set_xticklabels(('', -110, -100, -90, -80, -70, -60), color='k', size=13);
plt.setp(ax.get_yticklabels(), color="black", size=13)
plt.setp(ax.get_xticklabels(), color="black", size=13);
#for ax in fig.axes:
#    ax.tick_params(labelrotation=70);
