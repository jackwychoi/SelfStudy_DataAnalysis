# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib.colors as mcolors
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Polygon
import missingno as msno
import os
import wget
import openpyxl
import math

# %%
# download the data excel file from the USDA website to local folder
filename = wget.download("https://www.ers.usda.gov/media/rbmpu1zi/mapdata2021.xlsx")
# load the excel file into a pandas dataframe & skip header rows
df = pd.read_excel(os.getcwd()+'/mapdata2021.xlsx',skiprows=4)
# rename the columns of interest
df = df.rename(columns={'Unnamed: 0':'state',
                       'Percent':'pct_food_insecure'})
# retain only the columns of interest
df = df[['state','pct_food_insecure']]

# take a look at the dataframe for missing values
msno.matrix(df)
# Out:
# <Axes: >

# %%
df = df[df.state.str.len()==2]
df.pct_food_insecure.hist()
# Out:
# <Axes: >

# %%
wget.download("https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_state_500k.zip")
# Out:
# 'cb_2018_us_state_500k (1).zip'

# %%
gdf = gpd.read_file('data/cb_2018_us_state_500k.shp')
gdf.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...
# 2  POLYGON ((-103.00257 36.52659, -103.00219 36.6...
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...
# 4  POLYGON ((-82.64320 38.16909, -82.64300 38.169...

# %%
gdf = gdf.merge(df,left_on='STUSPS',right_on='state')
gdf.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry state  pct_food_insecure
# 0  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...    MS               15.3
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...    NC               10.9
# 2  POLYGON ((-103.00257 36.52659, -103.00219 36.6...    OK               13.8
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...    VA                7.8
# 4  POLYGON ((-82.64320 38.16909, -82.64300 38.169...    WV               14.0

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# NOTE: the convention for polygon points is (Long, Lat)....counterintuitive
polygon = Polygon([(-175,50),(-175,72),(-140, 72),(-140,50)])
# polygon = Polygon([(-180,0),(-180,90),(-120,90),(-120,0)])

# polygon=hipolygon
poly_gdf = gpd.GeoDataFrame( geometry=[polygon], crs=world.crs)

fig, ax1 = plt.subplots(1, figsize=(8, 18))
world.plot(ax=ax1)
poly_gdf.boundary.plot(ax = ax1, color="red")
ax1.set_title("The red polygon can be used to clip Alaska's western islands", fontsize=20)
ax1.set_axis_off()
plt.show()
# Out:
# C:\Users\Wonyoung\AppData\Local\Temp\ipykernel_14740\4046812394.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
gdf = gdf.merge(df,left_on='STUSPS',right_on='state')
gdf.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry state_x  \
# 0  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...      MS
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...      NC
# 2  POLYGON ((-103.00257 36.52659, -103.00219 36.6...      OK
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...      VA
# 4  POLYGON ((-82.64320 38.16909, -82.64300 38.169...      WV
#
#    pct_food_insecure_x state_y  pct_food_insecure_y
# 0                 15.3      MS                 15.3
# 1                 10.9      NC                 10.9
# 2                 13.8      OK                 13.8
# 3                  7.8      VA                  7.8
# 4                 14.0      WV                 14.0

# %%
gdf.to_crs({'init':'epsg:2163'})
# Out:
# C:\Users\Wonyoung\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS                  NAME LSAD  \
# 0       28  01779790  0400000US28    28     MS           Mississippi   00
# 1       37  01027616  0400000US37    37     NC        North Carolina   00
# 2       40  01102857  0400000US40    40     OK              Oklahoma   00
# 3       51  01779803  0400000US51    51     VA              Virginia   00
# 4       54  01779805  0400000US54    54     WV         West Virginia   00
# 5       22  01629543  0400000US22    22     LA             Louisiana   00
# 6       26  01779789  0400000US26    26     MI              Michigan   00
# 7       25  00606926  0400000US25    25     MA         Massachusetts   00
# 8       16  01779783  0400000US16    16     ID                 Idaho   00
# 9       12  00294478  0400000US12    12     FL               Florida   00
# 10      31  01779792  0400000US31    31     NE              Nebraska   00
# 11      53  01779804  0400000US53    53     WA            Washington   00
# 12      35  00897535  0400000US35    35     NM            New Mexico   00
# 13      46  01785534  0400000US46    46     SD          South Dakota   00
# 14      48  01779801  0400000US48    48     TX                 Texas   00
# 15      06  01779778  0400000US06    06     CA            California   00
# 16      01  01779775  0400000US01    01     AL               Alabama   00
# 17      13  01705317  0400000US13    13     GA               Georgia   00
# 18      42  01779798  0400000US42    42     PA          Pennsylvania   00
# 19      29  01779791  0400000US29    29     MO              Missouri   00
# 20      08  01779779  0400000US08    08     CO              Colorado   00
# 21      49  01455989  0400000US49    49     UT                  Utah   00
# 22      47  01325873  0400000US47    47     TN             Tennessee   00
# 23      56  01779807  0400000US56    56     WY               Wyoming   00
# 24      36  01779796  0400000US36    36     NY              New York   00
# 25      20  00481813  0400000US20    20     KS                Kansas   00
# 26      02  01785533  0400000US02    02     AK                Alaska   00
# 27      32  01779793  0400000US32    32     NV                Nevada   00
# 28      17  01779784  0400000US17    17     IL              Illinois   00
# 29      50  01779802  0400000US50    50     VT               Vermont   00
# 30      30  00767982  0400000US30    30     MT               Montana   00
# 31      19  01779785  0400000US19    19     IA                  Iowa   00
# 32      45  01779799  0400000US45    45     SC        South Carolina   00
# 33      33  01779794  0400000US33    33     NH         New Hampshire   00
# 34      04  01779777  0400000US04    04     AZ               Arizona   00
# 35      11  01702382  0400000US11    11     DC  District of Columbia   00
# 36      34  01779795  0400000US34    34     NJ            New Jersey   00
# 37      24  01714934  0400000US24    24     MD              Maryland   00
# 38      23  01779787  0400000US23    23     ME                 Maine   00
# 39      15  01779782  0400000US15    15     HI                Hawaii   00
# 40      10  01779781  0400000US10    10     DE              Delaware   00
# 41      44  01219835  0400000US44    44     RI          Rhode Island   00
# 42      21  01779786  0400000US21    21     KY              Kentucky   00
# 43      39  01085497  0400000US39    39     OH                  Ohio   00
# 44      55  01779806  0400000US55    55     WI             Wisconsin   00
# 45      41  01155107  0400000US41    41     OR                Oregon   00
# 46      38  01779797  0400000US38    38     ND          North Dakota   00
# 47      05  00068085  0400000US05    05     AR              Arkansas   00
# 48      18  00448508  0400000US18    18     IN               Indiana   00
# 49      27  00662849  0400000US27    27     MN             Minnesota   00
# 50      09  01779780  0400000US09    09     CT           Connecticut   00
#
#             ALAND        AWATER  \
# 0    121533519481    3926919758
# 1    125923656064   13466071395
# 2    177662925723    3374587997
# 3    102257717110    8528531774
# 4     62266474513     489028543
# 5    111897594374   23753621895
# 6    146600952990  103885855702
# 7     20205125364    7129925486
# 8    214049787659    2391722557
# 9    138949136250   31361101223
# 10   198956658395    1371829134
# 11   172112588220   12559278850
# 12   314196306401     728776523
# 13   196346981786    3382720225
# 14   676653171537   19006305260
# 15   403503931312   20463871877
# 16   131174048583    4593327154
# 17   149482048342    4422936154
# 18   115884442321    3394589990
# 19   178050802184    2489425460
# 20   268422891711    1181621593
# 21   212886221680    6998824394
# 22   106802728188    2350123465
# 23   251458544898    1867670745
# 24   122049149763   19246994695
# 25   211755344060    1344141205
# 26  1478839695958  245481577452
# 27   284329506470    2047206072
# 28   143780567633    6214824948
# 29    23874175944    1030416650
# 30   376962738765    3869208832
# 31   144661267977    1084180812
# 32    77864918488    5075218778
# 33    23189413166    1026675248
# 34   294198551143    1027337603
# 35      158340391      18687198
# 36    19047825980    3544860246
# 37    25151100280    6979966958
# 38    79887426037   11746549764
# 39    16633990195   11777809026
# 40     5045925646    1399985648
# 41     2677779902    1323670487
# 42   102279490672    2375337755
# 43   105828882568   10268850702
# 44   140290039723   29344951758
# 45   248606993270    6192386935
# 46   178707534813    4403267548
# 47   134768872727    2962859592
# 48    92789302676    1538002829
# 49   206228939448   18945217189
# 50    12542497068    1815617571
#
#                                              geometry state_x  \
# 0   MULTIPOLYGON (((1109990.968 -1565553.473, 1111...      MS
# 1   MULTIPOLYGON (((2154835.730 -692236.318, 21554...      NC
# 2   POLYGON ((-268956.153 -936541.911, -268644.290...      OK
# 3   MULTIPOLYGON (((2098181.788 -490386.322, 20982...      VA
# 4   POLYGON ((1506493.502 -601384.449, 1506500.488...      WV
# 5   MULTIPOLYGON (((1079314.605 -1608998.456, 1079...      LA
# 6   MULTIPOLYGON (((1376552.929 -187673.161, 13766...      MI
# 7   MULTIPOLYGON (((2420821.628 34539.216, 2421740...      MA
# 8   POLYGON ((-1357097.048 78008.665, -1356418.733...      ID
# 9   MULTIPOLYGON (((1997737.502 -1929546.629, 1997...      FL
# 10  POLYGON ((-339300.107 -417388.905, -339152.688...      NE
# 11  MULTIPOLYGON (((-1634603.902 627555.336, -1634...      WA
# 12  POLYGON ((-862284.832 -1454476.300, -862055.89...      NM
# 13  POLYGON ((-318904.047 7722.249, -318345.973 77...      SD
# 14  MULTIPOLYGON (((514174.606 -1677406.041, 51426...      TX
# 15  MULTIPOLYGON (((-1717362.709 -1090134.236, -17...      CA
# 16  MULTIPOLYGON (((1149241.382 -1527641.924, 1149...      AL
# 17  MULTIPOLYGON (((1774030.600 -1324555.678, 1774...      GA
# 18  POLYGON ((1619194.622 -262054.080, 1618896.790...      PA
# 19  POLYGON ((357015.839 -482423.567, 357411.771 -...      MO
# 20  POLYGON ((-786661.937 -668512.657, -785229.222...      CO
# 21  POLYGON ((-1233557.946 -719049.047, -1233307.3...      UT
# 22  POLYGON ((883537.509 -1059425.357, 883512.958 ...      TN
# 23  POLYGON ((-865796.146 59349.771, -865059.040 5...      WY
# 24  MULTIPOLYGON (((2282987.133 -21612.117, 228292...      NY
# 25  POLYGON ((-174904.234 -553289.723, -163394.329...      KS
# 26  MULTIPOLYGON (((-4288629.978 3426273.416, -428...      AK
# 27  POLYGON ((-1704711.243 -434243.484, -1704304.7...      NV
# 28  POLYGON ((720075.715 -498698.791, 720152.042 -...      IL
# 29  POLYGON ((2075889.623 238837.861, 2075660.094 ...      VT
# 30  POLYGON ((-1172967.168 508069.445, -1172661.73...      MT
# 31  POLYGON ((274392.612 -245974.721, 274686.556 -...      IA
# 32  MULTIPOLYGON (((1898451.866 -1099821.381, 1898...      SC
# 33  MULTIPOLYGON (((2326386.715 202542.815, 232647...      NH
# 34  POLYGON ((-1389116.907 -1265584.638, -1388917....      AZ
# 35  POLYGON ((1950824.826 -402441.066, 1951257.117...      DC
# 36  POLYGON ((2057791.686 -289296.647, 2057740.367...      NJ
# 37  MULTIPOLYGON (((2067200.844 -478858.279, 20671...      MD
# 38  MULTIPOLYGON (((2495293.614 476103.925, 249529...      ME
# 39  MULTIPOLYGON (((-5544643.751 -943550.426, -554...      HI
# 40  MULTIPOLYGON (((2060803.219 -301773.581, 20609...      DE
# 41  MULTIPOLYGON (((2326255.712 41838.783, 2326299...      RI
# 42  MULTIPOLYGON (((946128.073 -881437.420, 946563...      KY
# 43  MULTIPOLYGON (((1422979.278 -227154.171, 14231...      OH
# 44  MULTIPOLYGON (((1013687.987 121600.964, 101375...      WI
# 45  MULTIPOLYGON (((-1782085.164 403838.698, -1782...      OR
# 46  POLYGON ((-296167.581 437078.796, -296154.288 ...      ND
# 47  POLYGON ((482008.677 -928930.330, 482025.129 -...      AR
# 48  POLYGON ((1041908.256 -714117.134, 1042164.721...      IN
# 49  MULTIPOLYGON (((772401.860 380231.362, 772437....      MN
# 50  MULTIPOLYGON (((2226895.268 -42553.028, 222681...      CT
#
#     pct_food_insecure_x state_y  pct_food_insecure_y
# 0                  15.3      MS                 15.3
# 1                  10.9      NC                 10.9
# 2                  13.8      OK                 13.8
# 3                   7.8      VA                  7.8
# 4                  14.0      WV                 14.0
# 5                  14.5      LA                 14.5
# 6                  11.4      MI                 11.4
# 7                   8.4      MA                  8.4
# 8                   9.8      ID                  9.8
# 9                   9.9      FL                  9.9
# 10                 10.6      NE                 10.6
# 11                  7.9      WA                  7.9
# 12                 11.5      NM                 11.5
# 13                  8.7      SD                  8.7
# 14                 13.7      TX                 13.7
# 15                  9.6      CA                  9.6
# 16                 13.1      AL                 13.1
# 17                  9.9      GA                  9.9
# 18                  9.2      PA                  9.2
# 19                 12.0      MO                 12.0
# 20                 10.5      CO                 10.5
# 21                 11.2      UT                 11.2
# 22                 11.2      TN                 11.2
# 23                 11.2      WY                 11.2
# 24                 10.3      NY                 10.3
# 25                 10.2      KS                 10.2
# 26                  9.5      AK                  9.5
# 27                 10.2      NV                 10.2
# 28                  9.4      IL                  9.4
# 29                  7.9      VT                  7.9
# 30                 10.4      MT                 10.4
# 31                  7.0      IA                  7.0
# 32                 12.6      SC                 12.6
# 33                  5.4      NH                  5.4
# 34                 10.1      AZ                 10.1
# 35                  9.0      DC                  9.0
# 36                  8.3      NJ                  8.3
# 37                  8.7      MD                  8.7
# 38                  9.5      ME                  9.5
# 39                  9.1      HI                  9.1
# 40                 11.2      DE                 11.2
# 41                  8.4      RI                  8.4
# 42                 12.3      KY                 12.3
# 43                 10.8      OH                 10.8
# 44                  9.9      WI                  9.9
# 45                 10.3      OR                 10.3
# 46                  7.7      ND                  7.7
# 47                 15.0      AR                 15.0
# 48                  9.7      IN                  9.7
# 49                  7.4      MN                  7.4
# 50                  9.6      CT                  9.6
