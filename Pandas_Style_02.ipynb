# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
jr = pd.read_csv('data/gmonpro_20221207_090716_Sim1_44011.csv', header=None)

# %%
jr.head(3)
# Out:
#                                                    0
# 0  PLMN;SYSTEM;XCI;xNBID;LOCAL_CID;LAC/TAC;PCI/PS...
# 1  44011;4;71726856;280183;8;211;251;1575;1800 B3...
# 2  44011;4;71726856;280183;8;211;251;1575;1800 B3...

# %%
jr = jr[0].str.split(';', expand=True)
jr.columns = jr.iloc[0]
jr.drop(0, inplace=True)
jr.reset_index(drop=True, inplace=True)
jr.rename(columns={'PCI/PSC/BSIC':'PCI', 'RSRP/RSCP':'RSRP', 'RSRQ/ECIO':'RSRQ', 'SNR':'SINR', 'LAT':'LAT_org', 'LON':'LON_org', 'TIME':'TIME_org'}, inplace=True)
jr.insert(0, 'LON', jr['LON_org'])
jr.insert(0, 'LAT', jr['LAT_org'])
jr.insert(0, 'TIME', jr['TIME_org'])
jr.drop(['LON_org', 'LAT_org', 'TIME_org'], axis=1, inplace=True)

# %%
jr.head(3)
# Out:
# 0      TIME        LAT         LON   PLMN SYSTEM       XCI   xNBID LOCAL_CID  \
# 0  09:07:16  35.698181  139.773952  44011      4  71726856  280183         8
# 1  09:07:17  35.698181  139.773952  44011      4  71726856  280183         8
# 2  09:07:18  35.698181  139.773952  44011      4  71726856  280183         8
#
# 0 LAC/TAC  PCI ARFCN     BAND RSSI RSRP RSRQ SINR CQI  TA DISTANCE DELTA_AZI  \
# 0     211  251  1575  1800 B3  -65  -92   -6  1.0
# 1     211  251  1575  1800 B3  -65  -92   -6  1.0      56
# 2     211  251  1575  1800 B3  -65  -92   -6  1.0      56
#
# 0 SPEED GPS_ACCURACY  UL   DL BANDWIDTH BANDWIDTHS CA NR_STATE NARFCN NR_BAND  \
# 0     0           25  22  120      5000          5  1     none
# 1     0           25  11    9      5000          5  1     none
# 2     0           25  69   27      5000          5  1     none
#
# 0 NR_PCI NR_SS_RSRP NR_SS_RSRQ NR_SS_SINR NR_CSI_RSRP NR_CSI_RSRQ NR_CSI_SINR  \
# 0
# 1
# 2
#
# 0 CLF_LABEL CLF_LOC                             CLF_DESC        DATE ROAMING
# 0        --      --  Cell not found in the clf database!  2022/12/07    HOME
# 1        --      --  Cell not found in the clf database!  2022/12/07    HOME
# 2        --      --  Cell not found in the clf database!  2022/12/07    HOME

# %%
jr[['xNBID', 'PCI']].value_counts()
# Out:
# xNBID   PCI
# 279397  33     110
# 280189  135     66
# 279397  158     23
# 280183  251     22
# 280070  135     19
# 279617  75      18
# 279592  260     17
# 279398  74      17
# 280209  317     17
# 279041  95      16
# 279592  241     10
# 280183  15      10
# 280189  322     10
# 279398  7        7
# 279394  202      7
# 279633  190      5
#         313      4
# 279770  110      3
# 279394  199      3
# 278920  365      2
# 279617  332      2
# 279041  123      2
# dtype: int64

# %%
jr.columns
# Out:
# Index(['TIME', 'LAT', 'LON', 'PLMN', 'SYSTEM', 'XCI', 'xNBID', 'LOCAL_CID',
#        'LAC/TAC', 'PCI', 'ARFCN', 'BAND', 'RSSI', 'RSRP', 'RSRQ', 'SINR',
#        'CQI', 'TA', 'DISTANCE', 'DELTA_AZI', 'SPEED', 'GPS_ACCURACY', 'UL',
#        'DL', 'BANDWIDTH', 'BANDWIDTHS', 'CA', 'NR_STATE', 'NARFCN', 'NR_BAND',
#        'NR_PCI', 'NR_SS_RSRP', 'NR_SS_RSRQ', 'NR_SS_SINR', 'NR_CSI_RSRP',
#        'NR_CSI_RSRQ', 'NR_CSI_SINR', 'CLF_LABEL', 'CLF_LOC', 'CLF_DESC',
#        'DATE', 'ROAMING'],
#       dtype='object', name=0)

# %%
cols = ['PCI', 'ARFCN', 'BAND', 'RSSI', 'RSRP', 'RSRQ', 'SINR', 'CQI', 'TA']
for i in cols:
    jr[i] = pd.to_numeric(jr[i], errors='coerce')

# %%
jr_enb = jr.groupby(['xNBID', 'PCI']).agg({'RSSI':'mean', 'RSRP':'mean', 'RSRQ':'mean', 'SINR':'mean'}).sort_values(['xNBID', 'PCI'], ascending=True)

# %%
jr_enb
# Out:
# 0                RSSI       RSRP       RSRQ      SINR
# xNBID  PCI
#        313 -55.000000 -93.000000 -20.000000  1.400000
# 278920 365 -63.000000 -89.000000 -16.000000 -0.300000
# 279041 95  -63.000000 -85.187500 -14.375000 -0.300000
#        123 -63.000000 -87.000000 -12.000000 -0.300000
# 279394 199 -55.000000 -87.000000 -13.000000  1.400000
#        202 -55.000000 -85.285714 -12.571429  1.400000
# 279397 33  -61.581818 -81.972727 -11.545455  0.065455
#        158 -58.304348 -90.956522 -12.086957  1.039130
# 279398 7   -55.000000 -80.571429 -13.000000  1.400000
#        74  -55.000000 -93.294118 -17.882353  1.188235
# 279592 241 -55.000000 -85.900000 -13.200000  1.400000
#        260 -56.882353 -85.882353 -10.235294  1.094118
# 279617 75  -63.000000 -89.444444 -13.833333 -0.300000
#        332 -63.000000 -85.000000 -15.000000 -0.300000
# 279633 190 -55.000000 -85.800000 -13.400000  1.400000
# 279770 110 -63.000000 -88.000000 -10.000000  0.100000
# 280070 135 -55.000000 -89.631579 -10.894737  0.600000
# 280183 15  -68.600000 -94.800000 -13.500000  0.140000
#        251 -69.363636 -97.045455  -9.045455  0.927273
# 280189 135 -55.000000 -75.424242  -4.666667  1.400000
#        322 -55.000000 -81.400000  -8.900000  1.400000
# 280209 317 -55.000000 -77.588235 -11.882353  1.400000

# %%
jr_enb.style.highlight_null()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a48bc_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a48bc_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_a48bc_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_a48bc_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_a48bc_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_a48bc_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_a48bc_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row1" class="row_heading level0 row1" >278920</th>
#       <th id="T_a48bc_level1_row1" class="row_heading level1 row1" >365</th>
#       <td id="T_a48bc_row1_col0" class="data row1 col0" >-63.000000</td>
#       <td id="T_a48bc_row1_col1" class="data row1 col1" >-89.000000</td>
#       <td id="T_a48bc_row1_col2" class="data row1 col2" >-16.000000</td>
#       <td id="T_a48bc_row1_col3" class="data row1 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row2" class="row_heading level0 row2" rowspan="2">279041</th>
#       <th id="T_a48bc_level1_row2" class="row_heading level1 row2" >95</th>
#       <td id="T_a48bc_row2_col0" class="data row2 col0" >-63.000000</td>
#       <td id="T_a48bc_row2_col1" class="data row2 col1" >-85.187500</td>
#       <td id="T_a48bc_row2_col2" class="data row2 col2" >-14.375000</td>
#       <td id="T_a48bc_row2_col3" class="data row2 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level1_row3" class="row_heading level1 row3" >123</th>
#       <td id="T_a48bc_row3_col0" class="data row3 col0" >-63.000000</td>
#       <td id="T_a48bc_row3_col1" class="data row3 col1" >-87.000000</td>
#       <td id="T_a48bc_row3_col2" class="data row3 col2" >-12.000000</td>
#       <td id="T_a48bc_row3_col3" class="data row3 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row4" class="row_heading level0 row4" rowspan="2">279394</th>
#       <th id="T_a48bc_level1_row4" class="row_heading level1 row4" >199</th>
#       <td id="T_a48bc_row4_col0" class="data row4 col0" >-55.000000</td>
#       <td id="T_a48bc_row4_col1" class="data row4 col1" >-87.000000</td>
#       <td id="T_a48bc_row4_col2" class="data row4 col2" >-13.000000</td>
#       <td id="T_a48bc_row4_col3" class="data row4 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level1_row5" class="row_heading level1 row5" >202</th>
#       <td id="T_a48bc_row5_col0" class="data row5 col0" >-55.000000</td>
#       <td id="T_a48bc_row5_col1" class="data row5 col1" >-85.285714</td>
#       <td id="T_a48bc_row5_col2" class="data row5 col2" >-12.571429</td>
#       <td id="T_a48bc_row5_col3" class="data row5 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row6" class="row_heading level0 row6" rowspan="2">279397</th>
#       <th id="T_a48bc_level1_row6" class="row_heading level1 row6" >33</th>
#       <td id="T_a48bc_row6_col0" class="data row6 col0" >-61.581818</td>
#       <td id="T_a48bc_row6_col1" class="data row6 col1" >-81.972727</td>
#       <td id="T_a48bc_row6_col2" class="data row6 col2" >-11.545455</td>
#       <td id="T_a48bc_row6_col3" class="data row6 col3" >0.065455</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level1_row7" class="row_heading level1 row7" >158</th>
#       <td id="T_a48bc_row7_col0" class="data row7 col0" >-58.304348</td>
#       <td id="T_a48bc_row7_col1" class="data row7 col1" >-90.956522</td>
#       <td id="T_a48bc_row7_col2" class="data row7 col2" >-12.086957</td>
#       <td id="T_a48bc_row7_col3" class="data row7 col3" >1.039130</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row8" class="row_heading level0 row8" rowspan="2">279398</th>
#       <th id="T_a48bc_level1_row8" class="row_heading level1 row8" >7</th>
#       <td id="T_a48bc_row8_col0" class="data row8 col0" >-55.000000</td>
#       <td id="T_a48bc_row8_col1" class="data row8 col1" >-80.571429</td>
#       <td id="T_a48bc_row8_col2" class="data row8 col2" >-13.000000</td>
#       <td id="T_a48bc_row8_col3" class="data row8 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level1_row9" class="row_heading level1 row9" >74</th>
#       <td id="T_a48bc_row9_col0" class="data row9 col0" >-55.000000</td>
#       <td id="T_a48bc_row9_col1" class="data row9 col1" >-93.294118</td>
#       <td id="T_a48bc_row9_col2" class="data row9 col2" >-17.882353</td>
#       <td id="T_a48bc_row9_col3" class="data row9 col3" >1.188235</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row10" class="row_heading level0 row10" rowspan="2">279592</th>
#       <th id="T_a48bc_level1_row10" class="row_heading level1 row10" >241</th>
#       <td id="T_a48bc_row10_col0" class="data row10 col0" >-55.000000</td>
#       <td id="T_a48bc_row10_col1" class="data row10 col1" >-85.900000</td>
#       <td id="T_a48bc_row10_col2" class="data row10 col2" >-13.200000</td>
#       <td id="T_a48bc_row10_col3" class="data row10 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level1_row11" class="row_heading level1 row11" >260</th>
#       <td id="T_a48bc_row11_col0" class="data row11 col0" >-56.882353</td>
#       <td id="T_a48bc_row11_col1" class="data row11 col1" >-85.882353</td>
#       <td id="T_a48bc_row11_col2" class="data row11 col2" >-10.235294</td>
#       <td id="T_a48bc_row11_col3" class="data row11 col3" >1.094118</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row12" class="row_heading level0 row12" rowspan="2">279617</th>
#       <th id="T_a48bc_level1_row12" class="row_heading level1 row12" >75</th>
#       <td id="T_a48bc_row12_col0" class="data row12 col0" >-63.000000</td>
#       <td id="T_a48bc_row12_col1" class="data row12 col1" >-89.444444</td>
#       <td id="T_a48bc_row12_col2" class="data row12 col2" >-13.833333</td>
#       <td id="T_a48bc_row12_col3" class="data row12 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level1_row13" class="row_heading level1 row13" >332</th>
#       <td id="T_a48bc_row13_col0" class="data row13 col0" >-63.000000</td>
#       <td id="T_a48bc_row13_col1" class="data row13 col1" >-85.000000</td>
#       <td id="T_a48bc_row13_col2" class="data row13 col2" >-15.000000</td>
#       <td id="T_a48bc_row13_col3" class="data row13 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row14" class="row_heading level0 row14" >279633</th>
#       <th id="T_a48bc_level1_row14" class="row_heading level1 row14" >190</th>
#       <td id="T_a48bc_row14_col0" class="data row14 col0" >-55.000000</td>
#       <td id="T_a48bc_row14_col1" class="data row14 col1" >-85.800000</td>
#       <td id="T_a48bc_row14_col2" class="data row14 col2" >-13.400000</td>
#       <td id="T_a48bc_row14_col3" class="data row14 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row15" class="row_heading level0 row15" >279770</th>
#       <th id="T_a48bc_level1_row15" class="row_heading level1 row15" >110</th>
#       <td id="T_a48bc_row15_col0" class="data row15 col0" >-63.000000</td>
#       <td id="T_a48bc_row15_col1" class="data row15 col1" >-88.000000</td>
#       <td id="T_a48bc_row15_col2" class="data row15 col2" >-10.000000</td>
#       <td id="T_a48bc_row15_col3" class="data row15 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_a48bc_level0_row16" class="row_heading level0 row16" >280070</th>
#       <th id="T_a48bc_level1_row16" class="row_heading level1 row16" >135</th>
#       <td id="T_a48bc_row16_col0" class="data ro

# %%
jr_enb.style.highlight_max(props='color:white;background-color:blue')
# Out:
# <style type="text/css">
# #T_7887c_row0_col0, #T_7887c_row0_col3, #T_7887c_row4_col0, #T_7887c_row5_col0, #T_7887c_row5_col3, #T_7887c_row8_col0, #T_7887c_row8_col3, #T_7887c_row9_col0, #T_7887c_row10_col0, #T_7887c_row10_col3, #T_7887c_row14_col0, #T_7887c_row14_col3, #T_7887c_row16_col0, #T_7887c_row19_col0, #T_7887c_row19_col1, #T_7887c_row19_col2, #T_7887c_row19_col3, #T_7887c_row20_col0, #T_7887c_row20_col3, #T_7887c_row21_col0, #T_7887c_row21_col3 {
#   color: white;
#   background-color: blue;
# }
# </style>
# <table id="T_7887c_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7887c_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_7887c_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_7887c_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_7887c_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_7887c_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_7887c_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row1" class="row_heading level0 row1" >278920</th>
#       <th id="T_7887c_level1_row1" class="row_heading level1 row1" >365</th>
#       <td id="T_7887c_row1_col0" class="data row1 col0" >-63.000000</td>
#       <td id="T_7887c_row1_col1" class="data row1 col1" >-89.000000</td>
#       <td id="T_7887c_row1_col2" class="data row1 col2" >-16.000000</td>
#       <td id="T_7887c_row1_col3" class="data row1 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row2" class="row_heading level0 row2" rowspan="2">279041</th>
#       <th id="T_7887c_level1_row2" class="row_heading level1 row2" >95</th>
#       <td id="T_7887c_row2_col0" class="data row2 col0" >-63.000000</td>
#       <td id="T_7887c_row2_col1" class="data row2 col1" >-85.187500</td>
#       <td id="T_7887c_row2_col2" class="data row2 col2" >-14.375000</td>
#       <td id="T_7887c_row2_col3" class="data row2 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level1_row3" class="row_heading level1 row3" >123</th>
#       <td id="T_7887c_row3_col0" class="data row3 col0" >-63.000000</td>
#       <td id="T_7887c_row3_col1" class="data row3 col1" >-87.000000</td>
#       <td id="T_7887c_row3_col2" class="data row3 col2" >-12.000000</td>
#       <td id="T_7887c_row3_col3" class="data row3 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row4" class="row_heading level0 row4" rowspan="2">279394</th>
#       <th id="T_7887c_level1_row4" class="row_heading level1 row4" >199</th>
#       <td id="T_7887c_row4_col0" class="data row4 col0" >-55.000000</td>
#       <td id="T_7887c_row4_col1" class="data row4 col1" >-87.000000</td>
#       <td id="T_7887c_row4_col2" class="data row4 col2" >-13.000000</td>
#       <td id="T_7887c_row4_col3" class="data row4 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level1_row5" class="row_heading level1 row5" >202</th>
#       <td id="T_7887c_row5_col0" class="data row5 col0" >-55.000000</td>
#       <td id="T_7887c_row5_col1" class="data row5 col1" >-85.285714</td>
#       <td id="T_7887c_row5_col2" class="data row5 col2" >-12.571429</td>
#       <td id="T_7887c_row5_col3" class="data row5 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row6" class="row_heading level0 row6" rowspan="2">279397</th>
#       <th id="T_7887c_level1_row6" class="row_heading level1 row6" >33</th>
#       <td id="T_7887c_row6_col0" class="data row6 col0" >-61.581818</td>
#       <td id="T_7887c_row6_col1" class="data row6 col1" >-81.972727</td>
#       <td id="T_7887c_row6_col2" class="data row6 col2" >-11.545455</td>
#       <td id="T_7887c_row6_col3" class="data row6 col3" >0.065455</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level1_row7" class="row_heading level1 row7" >158</th>
#       <td id="T_7887c_row7_col0" class="data row7 col0" >-58.304348</td>
#       <td id="T_7887c_row7_col1" class="data row7 col1" >-90.956522</td>
#       <td id="T_7887c_row7_col2" class="data row7 col2" >-12.086957</td>
#       <td id="T_7887c_row7_col3" class="data row7 col3" >1.039130</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row8" class="row_heading level0 row8" rowspan="2">279398</th>
#       <th id="T_7887c_level1_row8" class="row_heading level1 row8" >7</th>
#       <td id="T_7887c_row8_col0" class="data row8 col0" >-55.000000</td>
#       <td id="T_7887c_row8_col1" class="data row8 col1" >-80.571429</td>
#       <td id="T_7887c_row8_col2" class="data row8 col2" >-13.000000</td>
#       <td id="T_7887c_row8_col3" class="data row8 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level1_row9" class="row_heading level1 row9" >74</th>
#       <td id="T_7887c_row9_col0" class="data row9 col0" >-55.000000</td>
#       <td id="T_7887c_row9_col1" class="data row9 col1" >-93.294118</td>
#       <td id="T_7887c_row9_col2" class="data row9 col2" >-17.882353</td>
#       <td id="T_7887c_row9_col3" class="data row9 col3" >1.188235</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row10" class="row_heading level0 row10" rowspan="2">279592</th>
#       <th id="T_7887c_level1_row10" class="row_heading level1 row10" >241</th>
#       <td id="T_7887c_row10_col0" class="data row10 col0" >-55.000000</td>
#       <td id="T_7887c_row10_col1" class="data row10 col1" >-85.900000</td>
#       <td id="T_7887c_row10_col2" class="data row10 col2" >-13.200000</td>
#       <td id="T_7887c_row10_col3" class="data row10 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level1_row11" class="row_heading level1 row11" >260</th>
#       <td id="T_7887c_row11_col0" class="data row11 col0" >-56.882353</td>
#       <td id="T_7887c_row11_col1" class="data row11 col1" >-85.882353</td>
#       <td id="T_7887c_row11_col2" class="data row11 col2" >-10.235294</td>
#       <td id="T_7887c_row11_col3" class="data row11 col3" >1.094118</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row12" class="row_heading level0 row12" rowspan="2">279617</th>
#       <th id="T_7887c_level1_row12" class="row_heading level1 row12" >75</th>
#       <td id="T_7887c_row12_col0" class="data row12 col0" >-63.000000</td>
#       <td id="T_7887c_row12_col1" class="data row12 col1" >-89.444444</td>
#       <td id="T_7887c_row12_col2" class="data row12 col2" >-13.833333</td>
#       <td id="T_7887c_row12_col3" class="data row12 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level1_row13" class="row_heading level1 row13" >332</th>
#       <td id="T_7887c_row13_col0" class="data row13 col0" >-63.000000</td>
#       <td id="T_7887c_row13_col1" class="data row13 col1" >-85.000000</td>
#       <td id="T_7887c_row13_col2" class="data row13 col2" >-15.000000</td>
#       <td id="T_7887c_row13_col3" class="data row13 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row14" class="row_heading level0 row14" >279633</th>
#       <th id="T_7887c_level1_row14" class="row_heading level1 row14" >190</th>
#       <td id="T_7887c_row14_col0" class="data row14 col0" >-55.000000</td>
#       <td id="T_7887c_row14_col1" class="data row14 col1" >-85.800000</td>
#       <td id="T_7887c_row14_col2" class="data row14 col2" >-13.400000</td>
#       <td id="T_7887c_row14_col3" class="data row14 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7887c_level0_row15" class="row_heading level0 row15" >279770</th>
#       <th id="T_7887c_level1_row15" class="row_heading level1 row15" >110</th>
#       <td id="T_7887c_row15_col0" class="data ro

# %%
jr_enb.style.highlight_min(props='color:white;background-color:red')
# Out:
# <style type="text/css">
# #T_81986_row0_col2, #T_81986_row1_col3, #T_81986_row2_col3, #T_81986_row3_col3, #T_81986_row12_col3, #T_81986_row13_col3, #T_81986_row18_col0, #T_81986_row18_col1 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_81986_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81986_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_81986_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_81986_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_81986_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_81986_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_81986_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row1" class="row_heading level0 row1" >278920</th>
#       <th id="T_81986_level1_row1" class="row_heading level1 row1" >365</th>
#       <td id="T_81986_row1_col0" class="data row1 col0" >-63.000000</td>
#       <td id="T_81986_row1_col1" class="data row1 col1" >-89.000000</td>
#       <td id="T_81986_row1_col2" class="data row1 col2" >-16.000000</td>
#       <td id="T_81986_row1_col3" class="data row1 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row2" class="row_heading level0 row2" rowspan="2">279041</th>
#       <th id="T_81986_level1_row2" class="row_heading level1 row2" >95</th>
#       <td id="T_81986_row2_col0" class="data row2 col0" >-63.000000</td>
#       <td id="T_81986_row2_col1" class="data row2 col1" >-85.187500</td>
#       <td id="T_81986_row2_col2" class="data row2 col2" >-14.375000</td>
#       <td id="T_81986_row2_col3" class="data row2 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level1_row3" class="row_heading level1 row3" >123</th>
#       <td id="T_81986_row3_col0" class="data row3 col0" >-63.000000</td>
#       <td id="T_81986_row3_col1" class="data row3 col1" >-87.000000</td>
#       <td id="T_81986_row3_col2" class="data row3 col2" >-12.000000</td>
#       <td id="T_81986_row3_col3" class="data row3 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row4" class="row_heading level0 row4" rowspan="2">279394</th>
#       <th id="T_81986_level1_row4" class="row_heading level1 row4" >199</th>
#       <td id="T_81986_row4_col0" class="data row4 col0" >-55.000000</td>
#       <td id="T_81986_row4_col1" class="data row4 col1" >-87.000000</td>
#       <td id="T_81986_row4_col2" class="data row4 col2" >-13.000000</td>
#       <td id="T_81986_row4_col3" class="data row4 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level1_row5" class="row_heading level1 row5" >202</th>
#       <td id="T_81986_row5_col0" class="data row5 col0" >-55.000000</td>
#       <td id="T_81986_row5_col1" class="data row5 col1" >-85.285714</td>
#       <td id="T_81986_row5_col2" class="data row5 col2" >-12.571429</td>
#       <td id="T_81986_row5_col3" class="data row5 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row6" class="row_heading level0 row6" rowspan="2">279397</th>
#       <th id="T_81986_level1_row6" class="row_heading level1 row6" >33</th>
#       <td id="T_81986_row6_col0" class="data row6 col0" >-61.581818</td>
#       <td id="T_81986_row6_col1" class="data row6 col1" >-81.972727</td>
#       <td id="T_81986_row6_col2" class="data row6 col2" >-11.545455</td>
#       <td id="T_81986_row6_col3" class="data row6 col3" >0.065455</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level1_row7" class="row_heading level1 row7" >158</th>
#       <td id="T_81986_row7_col0" class="data row7 col0" >-58.304348</td>
#       <td id="T_81986_row7_col1" class="data row7 col1" >-90.956522</td>
#       <td id="T_81986_row7_col2" class="data row7 col2" >-12.086957</td>
#       <td id="T_81986_row7_col3" class="data row7 col3" >1.039130</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row8" class="row_heading level0 row8" rowspan="2">279398</th>
#       <th id="T_81986_level1_row8" class="row_heading level1 row8" >7</th>
#       <td id="T_81986_row8_col0" class="data row8 col0" >-55.000000</td>
#       <td id="T_81986_row8_col1" class="data row8 col1" >-80.571429</td>
#       <td id="T_81986_row8_col2" class="data row8 col2" >-13.000000</td>
#       <td id="T_81986_row8_col3" class="data row8 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level1_row9" class="row_heading level1 row9" >74</th>
#       <td id="T_81986_row9_col0" class="data row9 col0" >-55.000000</td>
#       <td id="T_81986_row9_col1" class="data row9 col1" >-93.294118</td>
#       <td id="T_81986_row9_col2" class="data row9 col2" >-17.882353</td>
#       <td id="T_81986_row9_col3" class="data row9 col3" >1.188235</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row10" class="row_heading level0 row10" rowspan="2">279592</th>
#       <th id="T_81986_level1_row10" class="row_heading level1 row10" >241</th>
#       <td id="T_81986_row10_col0" class="data row10 col0" >-55.000000</td>
#       <td id="T_81986_row10_col1" class="data row10 col1" >-85.900000</td>
#       <td id="T_81986_row10_col2" class="data row10 col2" >-13.200000</td>
#       <td id="T_81986_row10_col3" class="data row10 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level1_row11" class="row_heading level1 row11" >260</th>
#       <td id="T_81986_row11_col0" class="data row11 col0" >-56.882353</td>
#       <td id="T_81986_row11_col1" class="data row11 col1" >-85.882353</td>
#       <td id="T_81986_row11_col2" class="data row11 col2" >-10.235294</td>
#       <td id="T_81986_row11_col3" class="data row11 col3" >1.094118</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row12" class="row_heading level0 row12" rowspan="2">279617</th>
#       <th id="T_81986_level1_row12" class="row_heading level1 row12" >75</th>
#       <td id="T_81986_row12_col0" class="data row12 col0" >-63.000000</td>
#       <td id="T_81986_row12_col1" class="data row12 col1" >-89.444444</td>
#       <td id="T_81986_row12_col2" class="data row12 col2" >-13.833333</td>
#       <td id="T_81986_row12_col3" class="data row12 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level1_row13" class="row_heading level1 row13" >332</th>
#       <td id="T_81986_row13_col0" class="data row13 col0" >-63.000000</td>
#       <td id="T_81986_row13_col1" class="data row13 col1" >-85.000000</td>
#       <td id="T_81986_row13_col2" class="data row13 col2" >-15.000000</td>
#       <td id="T_81986_row13_col3" class="data row13 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row14" class="row_heading level0 row14" >279633</th>
#       <th id="T_81986_level1_row14" class="row_heading level1 row14" >190</th>
#       <td id="T_81986_row14_col0" class="data row14 col0" >-55.000000</td>
#       <td id="T_81986_row14_col1" class="data row14 col1" >-85.800000</td>
#       <td id="T_81986_row14_col2" class="data row14 col2" >-13.400000</td>
#       <td id="T_81986_row14_col3" class="data row14 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_81986_level0_row15" class="row_heading level0 row15" >279770</th>
#       <th id="T_81986_level1_row15" class="row_heading level1 row15" >110</th>
#       <td id="T_81986_row15_col0" class="data row15 col0" >-63.000000</td>
#       <td id="T_81986_row15_col1" class="data row15 col1" >-88.000000</td>
#       <td id="T_81986_row15_col2" class="data row15 col2" >-10.000000</td>
#       <td id="T_81986_row15_col3" class="data row15 col3" >0.100000</td>
#     </tr>
#     <tr>

# %%
jr_enb.style.highlight_between(left=-85, right=-70, props='color:white;background-color:lime')
# Out:
# <style type="text/css">
# #T_8e999_row6_col1, #T_8e999_row8_col1, #T_8e999_row13_col1, #T_8e999_row19_col1, #T_8e999_row20_col1, #T_8e999_row21_col1 {
#   color: white;
#   background-color: lime;
# }
# </style>
# <table id="T_8e999_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e999_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_8e999_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_8e999_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_8e999_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_8e999_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_8e999_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row1" class="row_heading level0 row1" >278920</th>
#       <th id="T_8e999_level1_row1" class="row_heading level1 row1" >365</th>
#       <td id="T_8e999_row1_col0" class="data row1 col0" >-63.000000</td>
#       <td id="T_8e999_row1_col1" class="data row1 col1" >-89.000000</td>
#       <td id="T_8e999_row1_col2" class="data row1 col2" >-16.000000</td>
#       <td id="T_8e999_row1_col3" class="data row1 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row2" class="row_heading level0 row2" rowspan="2">279041</th>
#       <th id="T_8e999_level1_row2" class="row_heading level1 row2" >95</th>
#       <td id="T_8e999_row2_col0" class="data row2 col0" >-63.000000</td>
#       <td id="T_8e999_row2_col1" class="data row2 col1" >-85.187500</td>
#       <td id="T_8e999_row2_col2" class="data row2 col2" >-14.375000</td>
#       <td id="T_8e999_row2_col3" class="data row2 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level1_row3" class="row_heading level1 row3" >123</th>
#       <td id="T_8e999_row3_col0" class="data row3 col0" >-63.000000</td>
#       <td id="T_8e999_row3_col1" class="data row3 col1" >-87.000000</td>
#       <td id="T_8e999_row3_col2" class="data row3 col2" >-12.000000</td>
#       <td id="T_8e999_row3_col3" class="data row3 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row4" class="row_heading level0 row4" rowspan="2">279394</th>
#       <th id="T_8e999_level1_row4" class="row_heading level1 row4" >199</th>
#       <td id="T_8e999_row4_col0" class="data row4 col0" >-55.000000</td>
#       <td id="T_8e999_row4_col1" class="data row4 col1" >-87.000000</td>
#       <td id="T_8e999_row4_col2" class="data row4 col2" >-13.000000</td>
#       <td id="T_8e999_row4_col3" class="data row4 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level1_row5" class="row_heading level1 row5" >202</th>
#       <td id="T_8e999_row5_col0" class="data row5 col0" >-55.000000</td>
#       <td id="T_8e999_row5_col1" class="data row5 col1" >-85.285714</td>
#       <td id="T_8e999_row5_col2" class="data row5 col2" >-12.571429</td>
#       <td id="T_8e999_row5_col3" class="data row5 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row6" class="row_heading level0 row6" rowspan="2">279397</th>
#       <th id="T_8e999_level1_row6" class="row_heading level1 row6" >33</th>
#       <td id="T_8e999_row6_col0" class="data row6 col0" >-61.581818</td>
#       <td id="T_8e999_row6_col1" class="data row6 col1" >-81.972727</td>
#       <td id="T_8e999_row6_col2" class="data row6 col2" >-11.545455</td>
#       <td id="T_8e999_row6_col3" class="data row6 col3" >0.065455</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level1_row7" class="row_heading level1 row7" >158</th>
#       <td id="T_8e999_row7_col0" class="data row7 col0" >-58.304348</td>
#       <td id="T_8e999_row7_col1" class="data row7 col1" >-90.956522</td>
#       <td id="T_8e999_row7_col2" class="data row7 col2" >-12.086957</td>
#       <td id="T_8e999_row7_col3" class="data row7 col3" >1.039130</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row8" class="row_heading level0 row8" rowspan="2">279398</th>
#       <th id="T_8e999_level1_row8" class="row_heading level1 row8" >7</th>
#       <td id="T_8e999_row8_col0" class="data row8 col0" >-55.000000</td>
#       <td id="T_8e999_row8_col1" class="data row8 col1" >-80.571429</td>
#       <td id="T_8e999_row8_col2" class="data row8 col2" >-13.000000</td>
#       <td id="T_8e999_row8_col3" class="data row8 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level1_row9" class="row_heading level1 row9" >74</th>
#       <td id="T_8e999_row9_col0" class="data row9 col0" >-55.000000</td>
#       <td id="T_8e999_row9_col1" class="data row9 col1" >-93.294118</td>
#       <td id="T_8e999_row9_col2" class="data row9 col2" >-17.882353</td>
#       <td id="T_8e999_row9_col3" class="data row9 col3" >1.188235</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row10" class="row_heading level0 row10" rowspan="2">279592</th>
#       <th id="T_8e999_level1_row10" class="row_heading level1 row10" >241</th>
#       <td id="T_8e999_row10_col0" class="data row10 col0" >-55.000000</td>
#       <td id="T_8e999_row10_col1" class="data row10 col1" >-85.900000</td>
#       <td id="T_8e999_row10_col2" class="data row10 col2" >-13.200000</td>
#       <td id="T_8e999_row10_col3" class="data row10 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level1_row11" class="row_heading level1 row11" >260</th>
#       <td id="T_8e999_row11_col0" class="data row11 col0" >-56.882353</td>
#       <td id="T_8e999_row11_col1" class="data row11 col1" >-85.882353</td>
#       <td id="T_8e999_row11_col2" class="data row11 col2" >-10.235294</td>
#       <td id="T_8e999_row11_col3" class="data row11 col3" >1.094118</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row12" class="row_heading level0 row12" rowspan="2">279617</th>
#       <th id="T_8e999_level1_row12" class="row_heading level1 row12" >75</th>
#       <td id="T_8e999_row12_col0" class="data row12 col0" >-63.000000</td>
#       <td id="T_8e999_row12_col1" class="data row12 col1" >-89.444444</td>
#       <td id="T_8e999_row12_col2" class="data row12 col2" >-13.833333</td>
#       <td id="T_8e999_row12_col3" class="data row12 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level1_row13" class="row_heading level1 row13" >332</th>
#       <td id="T_8e999_row13_col0" class="data row13 col0" >-63.000000</td>
#       <td id="T_8e999_row13_col1" class="data row13 col1" >-85.000000</td>
#       <td id="T_8e999_row13_col2" class="data row13 col2" >-15.000000</td>
#       <td id="T_8e999_row13_col3" class="data row13 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row14" class="row_heading level0 row14" >279633</th>
#       <th id="T_8e999_level1_row14" class="row_heading level1 row14" >190</th>
#       <td id="T_8e999_row14_col0" class="data row14 col0" >-55.000000</td>
#       <td id="T_8e999_row14_col1" class="data row14 col1" >-85.800000</td>
#       <td id="T_8e999_row14_col2" class="data row14 col2" >-13.400000</td>
#       <td id="T_8e999_row14_col3" class="data row14 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row15" class="row_heading level0 row15" >279770</th>
#       <th id="T_8e999_level1_row15" class="row_heading level1 row15" >110</th>
#       <td id="T_8e999_row15_col0" class="data row15 col0" >-63.000000</td>
#       <td id="T_8e999_row15_col1" class="data row15 col1" >-88.000000</td>
#       <td id="T_8e999_row15_col2" class="data row15 col2" >-10.000000</td>
#       <td id="T_8e999_row15_col3" class="data row15 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_8e999_level0_row16" clas

# %%
jr_enb.style.bar()
# Out:
# <style type="text/css">
# #T_4150e_row0_col0, #T_4150e_row0_col3, #T_4150e_row4_col0, #T_4150e_row4_col3, #T_4150e_row5_col0, #T_4150e_row5_col3, #T_4150e_row8_col0, #T_4150e_row8_col3, #T_4150e_row9_col0, #T_4150e_row10_col0, #T_4150e_row10_col3, #T_4150e_row14_col0, #T_4150e_row14_col3, #T_4150e_row16_col0, #T_4150e_row19_col0, #T_4150e_row19_col1, #T_4150e_row19_col2, #T_4150e_row19_col3, #T_4150e_row20_col0, #T_4150e_row20_col3, #T_4150e_row21_col0, #T_4150e_row21_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_4150e_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.7%, transparent 18.7%);
# }
# #T_4150e_row0_col2, #T_4150e_row1_col3, #T_4150e_row2_col3, #T_4150e_row3_col3, #T_4150e_row12_col3, #T_4150e_row13_col3, #T_4150e_row18_col0, #T_4150e_row18_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_4150e_row1_col0, #T_4150e_row2_col0, #T_4150e_row3_col0, #T_4150e_row10_col2, #T_4150e_row12_col0, #T_4150e_row13_col0, #T_4150e_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 44.3%, transparent 44.3%);
# }
# #T_4150e_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 37.2%, transparent 37.2%);
# }
# #T_4150e_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.1%, transparent 26.1%);
# }
# #T_4150e_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 54.8%, transparent 54.8%);
# }
# #T_4150e_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.7%, transparent 36.7%);
# }
# #T_4150e_row3_col1, #T_4150e_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 46.5%, transparent 46.5%);
# }
# #T_4150e_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.2%, transparent 52.2%);
# }
# #T_4150e_row4_col2, #T_4150e_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 45.7%, transparent 45.7%);
# }
# #T_4150e_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 54.4%, transparent 54.4%);
# }
# #T_4150e_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 48.4%, transparent 48.4%);
# }
# #T_4150e_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 54.2%, transparent 54.2%);
# }
# #T_4150e_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 69.7%, transparent 69.7%);
# }
# #T_4150e_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.1%, transparent 55.1%);
# }
# #T_4150e_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.5%, transparent 21.5%);
# }
# #T_4150e_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 77.0%, transparent 77.0%);
# }
# #T_4150e_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.2%, transparent 28.2%);
# }
# #T_4150e_row7_col2, #T_4150e_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 51.6%, transparent 51.6%);
# }
# #T_4150e_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 78.8%, transparent 78.8%);
# }
# #T_4150e_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 76.2%, transparent 76.2%);
# }
# #T_4150e_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.4%, transparent 17.4%);
# }
# #T_4150e_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.8%, transparent 13.8%);
# }
# #T_4150e_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.5%, transparent 87.5%);
# }
# #T_4150e_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 51.5%, transparent 51.5%);
# }
# #T_4150e_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 86.9%, transparent 86.9%);
# }
# #T_4150e_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 63.7%, transparent 63.7%);
# }
# #T_4150e_row11_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 82.0%, transparent 82.0%);
# }
# #T_4150e_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
# }
# #T_4150e_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.2%, transparent 40.2%);
# }
# #T_4150e_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.7%, transparent 55.7%);
# }
# #T_4150e_row13_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.6%, transparent 32.6%);
# }
# #T_4150e_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.0%, transparent 52.0%);
# }
# #T_4150e_row14_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.0%, transparent 43.0%);
# }
# #T_4150e_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 41.8%, transparent 41.8%);
# }
# #T_4150e_row15_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 65.2%, transparent 65.2%);
# }
# #T_4150e_row15_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.5%, transparent 23.5%);
# }
# #T_4150e_row16_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.3%, transparent 34.3%);
# }
# #T_4150e_row16_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.4%, transparent 59.4%);
# }
# #T_4150e_row16_col3, #T_4150e_row21_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.9%, transparent 52.9%);
# }
# #T_4150e_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.3%, transparent 5.3%);
# }
# #T_4150e_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.4%, transparent 10.4%);
# }
# #T_4150e_row17_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 42.4%, transparent 42.4%);
# }
# #T_4150e_row17_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
# }
# #T_4150e_row18_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 71.4%, transparent 71.4%);
# }
# #T_4150e_row18_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 72.2%, transparent 72.2%);
# }
# #T_4150e_row20_col1, #T_4150e_row20_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 72.4%, transparent 72.4%);
# }
# #T_4150e_row21_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
# }
# </style>
# <table id="T_4150e_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4150e_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_4150e_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_4150e_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_4150e_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_4150e_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_4150e_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_415

# %%
jr_enb.style.background_gradient(cmap='RdYlGn', subset=['RSRP'])
# Out:
# <style type="text/css">
# #T_a7ce9_row0_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_a7ce9_row1_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_a7ce9_row2_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_a7ce9_row3_col1, #T_a7ce9_row4_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_a7ce9_row5_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a7ce9_row6_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_a7ce9_row7_col1 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_a7ce9_row8_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_a7ce9_row9_col1 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_a7ce9_row10_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_a7ce9_row11_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_a7ce9_row12_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_a7ce9_row13_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_a7ce9_row14_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a7ce9_row15_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_a7ce9_row16_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a7ce9_row17_col1 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_a7ce9_row18_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a7ce9_row19_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a7ce9_row20_col1 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_a7ce9_row21_col1 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7ce9_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7ce9_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_a7ce9_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_a7ce9_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_a7ce9_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_a7ce9_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_a7ce9_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row1" class="row_heading level0 row1" >278920</th>
#       <th id="T_a7ce9_level1_row1" class="row_heading level1 row1" >365</th>
#       <td id="T_a7ce9_row1_col0" class="data row1 col0" >-63.000000</td>
#       <td id="T_a7ce9_row1_col1" class="data row1 col1" >-89.000000</td>
#       <td id="T_a7ce9_row1_col2" class="data row1 col2" >-16.000000</td>
#       <td id="T_a7ce9_row1_col3" class="data row1 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row2" class="row_heading level0 row2" rowspan="2">279041</th>
#       <th id="T_a7ce9_level1_row2" class="row_heading level1 row2" >95</th>
#       <td id="T_a7ce9_row2_col0" class="data row2 col0" >-63.000000</td>
#       <td id="T_a7ce9_row2_col1" class="data row2 col1" >-85.187500</td>
#       <td id="T_a7ce9_row2_col2" class="data row2 col2" >-14.375000</td>
#       <td id="T_a7ce9_row2_col3" class="data row2 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level1_row3" class="row_heading level1 row3" >123</th>
#       <td id="T_a7ce9_row3_col0" class="data row3 col0" >-63.000000</td>
#       <td id="T_a7ce9_row3_col1" class="data row3 col1" >-87.000000</td>
#       <td id="T_a7ce9_row3_col2" class="data row3 col2" >-12.000000</td>
#       <td id="T_a7ce9_row3_col3" class="data row3 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row4" class="row_heading level0 row4" rowspan="2">279394</th>
#       <th id="T_a7ce9_level1_row4" class="row_heading level1 row4" >199</th>
#       <td id="T_a7ce9_row4_col0" class="data row4 col0" >-55.000000</td>
#       <td id="T_a7ce9_row4_col1" class="data row4 col1" >-87.000000</td>
#       <td id="T_a7ce9_row4_col2" class="data row4 col2" >-13.000000</td>
#       <td id="T_a7ce9_row4_col3" class="data row4 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level1_row5" class="row_heading level1 row5" >202</th>
#       <td id="T_a7ce9_row5_col0" class="data row5 col0" >-55.000000</td>
#       <td id="T_a7ce9_row5_col1" class="data row5 col1" >-85.285714</td>
#       <td id="T_a7ce9_row5_col2" class="data row5 col2" >-12.571429</td>
#       <td id="T_a7ce9_row5_col3" class="data row5 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row6" class="row_heading level0 row6" rowspan="2">279397</th>
#       <th id="T_a7ce9_level1_row6" class="row_heading level1 row6" >33</th>
#       <td id="T_a7ce9_row6_col0" class="data row6 col0" >-61.581818</td>
#       <td id="T_a7ce9_row6_col1" class="data row6 col1" >-81.972727</td>
#       <td id="T_a7ce9_row6_col2" class="data row6 col2" >-11.545455</td>
#       <td id="T_a7ce9_row6_col3" class="data row6 col3" >0.065455</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level1_row7" class="row_heading level1 row7" >158</th>
#       <td id="T_a7ce9_row7_col0" class="data row7 col0" >-58.304348</td>
#       <td id="T_a7ce9_row7_col1" class="data row7 col1" >-90.956522</td>
#       <td id="T_a7ce9_row7_col2" class="data row7 col2" >-12.086957</td>
#       <td id="T_a7ce9_row7_col3" class="data row7 col3" >1.039130</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row8" class="row_heading level0 row8" rowspan="2">279398</th>
#       <th id="T_a7ce9_level1_row8" class="row_heading level1 row8" >7</th>
#       <td id="T_a7ce9_row8_col0" class="data row8 col0" >-55.000000</td>
#       <td id="T_a7ce9_row8_col1" class="data row8 col1" >-80.571429</td>
#       <td id="T_a7ce9_row8_col2" class="data row8 col2" >-13.000000</td>
#       <td id="T_a7ce9_row8_col3" class="data row8 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level1_row9" class="row_heading level1 row9" >74</th>
#       <td id="T_a7ce9_row9_col0" class="data row9 col0" >-55.000000</td>
#       <td id="T_a7ce9_row9_col1" class="data row9 col1" >-93.294118</td>
#       <td id="T_a7ce9_row9_col2" class="data row9 col2" >-17.882353</td>
#       <td id="T_a7ce9_row9_col3" class="data row9 col3" >1.188235</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row10" class="row_heading level0 row10" rowspan="2">279592</th>
#       <th id="T_a7ce9_level1_row10" class="row_heading level1 row10" >241</th>
#       <td id="T_a7ce9_row10_col0" class="data row10 col0" >-55.000000</td>
#       <td id="T_a7ce9_row10_col1" class="data row10 col1" >-85.900000</td>
#       <td id="T_a7ce9_row10_col2" class="data row10 col2" >-13.200000</td>
#       <td id="T_a7ce9_row10_col3" class="data row10 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level1_row11" class="row_heading level1 row11" >260</th>
#       <td id="T_a7ce9_row11_col0" class="data row11 col0" >-56.882353</td>
#       <td id="T_a7ce9_row11_col1" class="data row11 col1" >-85.882353</td>
#       <td id="T_a7ce9_row11_col2" class="data row11 col2" >-10.235294</td>
#       <td id="T_a7ce9_row11_col3" class="data row11 col3" >1.094118</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level0_row12" class="row_heading level0 row12" rowspan="2">279617</th>
#       <th id="T_a7ce9_level1_row12" class="row_heading level1 row12" >75</th>
#       <td id="T_a7ce9_row12_col0" class="data row12 col0" >-63.000000</td>
#       <td id="T_a7ce9_row12_col1" class="data row12 col1" >-89.444444</td>
#       <td id="T_a7ce9_row12_col2" class="data row12 col2" >-13.833333</td>
#       <td id="T_a7ce9_row12_col3" class="data row12 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a7ce9_level1_row13" class="row_heading level

# %%
def highlight_df(df, subset=None):
    df = df.style.highlight_max(props='color:blue;background-color:lightblue', subset=subset) \
           .highlight_min(props='color:red;background-color:lightpink', subset=subset) \
           .highlight_null(props='color:white;background-color:black', subset=subset)
    return df

# %%
highlight_df(jr_enb, subset=['RSRP'])
# Out:
# <style type="text/css">
# #T_0b972_row18_col1 {
#   color: red;
#   background-color: lightpink;
# }
# #T_0b972_row19_col1 {
#   color: blue;
#   background-color: lightblue;
# }
# </style>
# <table id="T_0b972_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >0</th>
#       <th class="col_heading level0 col0" >RSSI</th>
#       <th class="col_heading level0 col1" >RSRP</th>
#       <th class="col_heading level0 col2" >RSRQ</th>
#       <th class="col_heading level0 col3" >SINR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >xNBID</th>
#       <th class="index_name level1" >PCI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b972_level0_row0" class="row_heading level0 row0" ></th>
#       <th id="T_0b972_level1_row0" class="row_heading level1 row0" >313</th>
#       <td id="T_0b972_row0_col0" class="data row0 col0" >-55.000000</td>
#       <td id="T_0b972_row0_col1" class="data row0 col1" >-93.000000</td>
#       <td id="T_0b972_row0_col2" class="data row0 col2" >-20.000000</td>
#       <td id="T_0b972_row0_col3" class="data row0 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row1" class="row_heading level0 row1" >278920</th>
#       <th id="T_0b972_level1_row1" class="row_heading level1 row1" >365</th>
#       <td id="T_0b972_row1_col0" class="data row1 col0" >-63.000000</td>
#       <td id="T_0b972_row1_col1" class="data row1 col1" >-89.000000</td>
#       <td id="T_0b972_row1_col2" class="data row1 col2" >-16.000000</td>
#       <td id="T_0b972_row1_col3" class="data row1 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row2" class="row_heading level0 row2" rowspan="2">279041</th>
#       <th id="T_0b972_level1_row2" class="row_heading level1 row2" >95</th>
#       <td id="T_0b972_row2_col0" class="data row2 col0" >-63.000000</td>
#       <td id="T_0b972_row2_col1" class="data row2 col1" >-85.187500</td>
#       <td id="T_0b972_row2_col2" class="data row2 col2" >-14.375000</td>
#       <td id="T_0b972_row2_col3" class="data row2 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level1_row3" class="row_heading level1 row3" >123</th>
#       <td id="T_0b972_row3_col0" class="data row3 col0" >-63.000000</td>
#       <td id="T_0b972_row3_col1" class="data row3 col1" >-87.000000</td>
#       <td id="T_0b972_row3_col2" class="data row3 col2" >-12.000000</td>
#       <td id="T_0b972_row3_col3" class="data row3 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row4" class="row_heading level0 row4" rowspan="2">279394</th>
#       <th id="T_0b972_level1_row4" class="row_heading level1 row4" >199</th>
#       <td id="T_0b972_row4_col0" class="data row4 col0" >-55.000000</td>
#       <td id="T_0b972_row4_col1" class="data row4 col1" >-87.000000</td>
#       <td id="T_0b972_row4_col2" class="data row4 col2" >-13.000000</td>
#       <td id="T_0b972_row4_col3" class="data row4 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level1_row5" class="row_heading level1 row5" >202</th>
#       <td id="T_0b972_row5_col0" class="data row5 col0" >-55.000000</td>
#       <td id="T_0b972_row5_col1" class="data row5 col1" >-85.285714</td>
#       <td id="T_0b972_row5_col2" class="data row5 col2" >-12.571429</td>
#       <td id="T_0b972_row5_col3" class="data row5 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row6" class="row_heading level0 row6" rowspan="2">279397</th>
#       <th id="T_0b972_level1_row6" class="row_heading level1 row6" >33</th>
#       <td id="T_0b972_row6_col0" class="data row6 col0" >-61.581818</td>
#       <td id="T_0b972_row6_col1" class="data row6 col1" >-81.972727</td>
#       <td id="T_0b972_row6_col2" class="data row6 col2" >-11.545455</td>
#       <td id="T_0b972_row6_col3" class="data row6 col3" >0.065455</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level1_row7" class="row_heading level1 row7" >158</th>
#       <td id="T_0b972_row7_col0" class="data row7 col0" >-58.304348</td>
#       <td id="T_0b972_row7_col1" class="data row7 col1" >-90.956522</td>
#       <td id="T_0b972_row7_col2" class="data row7 col2" >-12.086957</td>
#       <td id="T_0b972_row7_col3" class="data row7 col3" >1.039130</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row8" class="row_heading level0 row8" rowspan="2">279398</th>
#       <th id="T_0b972_level1_row8" class="row_heading level1 row8" >7</th>
#       <td id="T_0b972_row8_col0" class="data row8 col0" >-55.000000</td>
#       <td id="T_0b972_row8_col1" class="data row8 col1" >-80.571429</td>
#       <td id="T_0b972_row8_col2" class="data row8 col2" >-13.000000</td>
#       <td id="T_0b972_row8_col3" class="data row8 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level1_row9" class="row_heading level1 row9" >74</th>
#       <td id="T_0b972_row9_col0" class="data row9 col0" >-55.000000</td>
#       <td id="T_0b972_row9_col1" class="data row9 col1" >-93.294118</td>
#       <td id="T_0b972_row9_col2" class="data row9 col2" >-17.882353</td>
#       <td id="T_0b972_row9_col3" class="data row9 col3" >1.188235</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row10" class="row_heading level0 row10" rowspan="2">279592</th>
#       <th id="T_0b972_level1_row10" class="row_heading level1 row10" >241</th>
#       <td id="T_0b972_row10_col0" class="data row10 col0" >-55.000000</td>
#       <td id="T_0b972_row10_col1" class="data row10 col1" >-85.900000</td>
#       <td id="T_0b972_row10_col2" class="data row10 col2" >-13.200000</td>
#       <td id="T_0b972_row10_col3" class="data row10 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level1_row11" class="row_heading level1 row11" >260</th>
#       <td id="T_0b972_row11_col0" class="data row11 col0" >-56.882353</td>
#       <td id="T_0b972_row11_col1" class="data row11 col1" >-85.882353</td>
#       <td id="T_0b972_row11_col2" class="data row11 col2" >-10.235294</td>
#       <td id="T_0b972_row11_col3" class="data row11 col3" >1.094118</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row12" class="row_heading level0 row12" rowspan="2">279617</th>
#       <th id="T_0b972_level1_row12" class="row_heading level1 row12" >75</th>
#       <td id="T_0b972_row12_col0" class="data row12 col0" >-63.000000</td>
#       <td id="T_0b972_row12_col1" class="data row12 col1" >-89.444444</td>
#       <td id="T_0b972_row12_col2" class="data row12 col2" >-13.833333</td>
#       <td id="T_0b972_row12_col3" class="data row12 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level1_row13" class="row_heading level1 row13" >332</th>
#       <td id="T_0b972_row13_col0" class="data row13 col0" >-63.000000</td>
#       <td id="T_0b972_row13_col1" class="data row13 col1" >-85.000000</td>
#       <td id="T_0b972_row13_col2" class="data row13 col2" >-15.000000</td>
#       <td id="T_0b972_row13_col3" class="data row13 col3" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row14" class="row_heading level0 row14" >279633</th>
#       <th id="T_0b972_level1_row14" class="row_heading level1 row14" >190</th>
#       <td id="T_0b972_row14_col0" class="data row14 col0" >-55.000000</td>
#       <td id="T_0b972_row14_col1" class="data row14 col1" >-85.800000</td>
#       <td id="T_0b972_row14_col2" class="data row14 col2" >-13.400000</td>
#       <td id="T_0b972_row14_col3" class="data row14 col3" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row15" class="row_heading level0 row15" >279770</th>
#       <th id="T_0b972_level1_row15" class="row_heading level1 row15" >110</th>
#       <td id="T_0b972_row15_col0" class="data row15 col0" >-63.000000</td>
#       <td id="T_0b972_row15_col1" class="data row15 col1" >-88.000000</td>
#       <td id="T_0b972_row15_col2" class="data row15 col2" >-10.000000</td>
#       <td id="T_0b972_row15_col3" class="data row15 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_0b972_level0_row16" class="row_heading level0 row16" >
