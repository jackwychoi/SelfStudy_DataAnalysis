# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = {'Name': ['Fernando Torres', 'Steven Gerrard', 'Luis Suarez', 'Mohamed Salah'],
        'Date of Birth': ['1984-03-20', '1980-05-30', '1987-01-24', '1992-06-15'],
        'Age': [39, 43, 37, 31],
        'Nationality': ['Spain', 'United Kingdom', 'Uruguay', 'Egypt'],
        'Income': [ 45403410, 29339838, 199396947,  99762487],
        'Contact': ['FT 012-345-6789', 'SG 012-345-6789', 'LS 012-345-6789', 'MS 012-345-6789']}
df = pd.DataFrame(data)
print(df)
# Out:
#               Name Date of Birth  Age     Nationality     Income  \
# 0  Fernando Torres    1984-03-20   39           Spain   45403410
# 1   Steven Gerrard    1980-05-30   43  United Kingdom   29339838
# 2      Luis Suarez    1987-01-24   37         Uruguay  199396947
# 3    Mohamed Salah    1992-06-15   31           Egypt   99762487
#
#            Contact
# 0  FT 012-345-6789
# 1  SG 012-345-6789
# 2  LS 012-345-6789
# 3  MS 012-345-6789

# %%
# Detecting missing values
print(df.isnull())
# Detecting non-missing values
print(df.notnull())
# Out:
#     Name  Date of Birth    Age  Nationality  Income  Contact
# 0  False          False  False        False   False    False
# 1  False          False  False        False   False    False
# 2  False          False  False        False   False    False
# 3  False          False  False        False   False    False
#    Name  Date of Birth   Age  Nationality  Income  Contact
# 0  True           True  True         True    True     True
# 1  True           True  True         True    True     True
# 2  True           True  True         True    True     True
# 3  True           True  True         True    True     True

# %%
df.dtypes
# Out:
# Name             object
# Date of Birth    object
# Age               int64
# Nationality      object
# Income            int64
# Contact          object
# dtype: object

# %%
# Removing rows with missing values
cleaned_df = df.dropna()

# Removing columns with missing values
cleaned_df = df.dropna(axis=1)

# %%
# Filling missing values with a specific value
filled_df = df.fillna(value=0)

# Filling missing values with the mean of the column
filled_df = df.fillna(value=df['Age'].mean())

# %%
# Linear interpolation
interpolated_df = df.interpolate(method='linear')

# %%
interpolated_df
# Out:
#               Name Date of Birth  Age     Nationality     Income  \
# 0  Fernando Torres    1984-03-20   39           Spain   45403410
# 1   Steven Gerrard    1980-05-30   43  United Kingdom   29339838
# 2      Luis Suarez    1987-01-24   37         Uruguay  199396947
# 3    Mohamed Salah    1992-06-15   31           Egypt   99762487
#
#            Contact
# 0  FT 012-345-6789
# 1  SG 012-345-6789
# 2  LS 012-345-6789
# 3  MS 012-345-6789

# %%
# Converting data types
df['Age'] = df['Age'].astype('float64')

# %%
# Converting to DateTime
df['Date of Birth'] = pd.to_datetime(df['Date of Birth'])

# %%
# Converting to categorical data
df['Nationality'] = df['Nationality'].astype('category')

# %%
# Stripping extra spaces
df['Name'] = df['Name'].str.strip()

# Changing to lower case
df['Nationality'] = df['Nationality'].str.lower()

df
# Out:
#               Name Date of Birth   Age     Nationality     Income  \
# 0  Fernando Torres    1984-03-20  39.0           spain   45403410
# 1   Steven Gerrard    1980-05-30  43.0  united kingdom   29339838
# 2      Luis Suarez    1987-01-24  37.0         uruguay  199396947
# 3    Mohamed Salah    1992-06-15  31.0           egypt   99762487
#
#            Contact
# 0  FT 012-345-6789
# 1  SG 012-345-6789
# 2  LS 012-345-6789
# 3  MS 012-345-6789

# %%
# Removing punctuation
df['Name'] = df['Name'].str.replace('[^\w\s]', '', regex=True)

# Splitting text into columns
df[['FirstName', 'LastName']] = df['Name'].str.split(' ', expand=True)

# Replacing text
df['Nationality'] = df['Nationality'].str.replace('united kingdom', 'uk')

# Changing to lower case
df['Nationality'] = df['Nationality'].str.upper()

df
# Out:
#               Name Date of Birth   Age Nationality     Income  \
# 0  Fernando Torres    1984-03-20  39.0       SPAIN   45403410
# 1   Steven Gerrard    1980-05-30  43.0          UK   29339838
# 2      Luis Suarez    1987-01-24  37.0     URUGUAY  199396947
# 3    Mohamed Salah    1992-06-15  31.0       EGYPT   99762487
#
#            Contact FirstName LastName
# 0  FT 012-345-6789  Fernando   Torres
# 1  SG 012-345-6789    Steven  Gerrard
# 2  LS 012-345-6789      Luis   Suarez
# 3  MS 012-345-6789   Mohamed    Salah

# %%
# Identifying duplicate rows
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
# Removing duplicate rows, keeping the first occurrence
df_no_duplicates = df.drop_duplicates(keep='first')
df_no_duplicates
# Out:
#               Name Date of Birth   Age Nationality     Income  \
# 0  Fernando Torres    1984-03-20  39.0       SPAIN   45403410
# 1   Steven Gerrard    1980-05-30  43.0          UK   29339838
# 2      Luis Suarez    1987-01-24  37.0     URUGUAY  199396947
# 3    Mohamed Salah    1992-06-15  31.0       EGYPT   99762487
#
#            Contact FirstName LastName
# 0  FT 012-345-6789  Fernando   Torres
# 1  SG 012-345-6789    Steven  Gerrard
# 2  LS 012-345-6789      Luis   Suarez
# 3  MS 012-345-6789   Mohamed    Salah

# %%
# Min-Max normalization
df['Age'] = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())

# Z-score normalization
df['Income'] = (df['Income'] - df['Income'].mean()) / df['Income'].std()

df
# Out:
#               Name Date of Birth       Age Nationality    Income  \
# 0  Fernando Torres    1984-03-20  0.666667       SPAIN -0.626145
# 1   Steven Gerrard    1980-05-30  1.000000          UK -0.835374
# 2      Luis Suarez    1987-01-24  0.500000     URUGUAY  1.379633
# 3    Mohamed Salah    1992-06-15  0.000000       EGYPT  0.081886
#
#            Contact FirstName LastName
# 0  FT 012-345-6789  Fernando   Torres
# 1  SG 012-345-6789    Steven  Gerrard
# 2  LS 012-345-6789      Luis   Suarez
# 3  MS 012-345-6789   Mohamed    Salah

# %%
# Log transformation
df['Log_Age'] = np.log(df['Age'] + 1)
df
# Out:
#               Name Date of Birth       Age Nationality    Income  \
# 0  Fernando Torres    1984-03-20  0.666667       SPAIN -0.626145
# 1   Steven Gerrard    1980-05-30  1.000000          UK -0.835374
# 2      Luis Suarez    1987-01-24  0.500000     URUGUAY  1.379633
# 3    Mohamed Salah    1992-06-15  0.000000       EGYPT  0.081886
#
#            Contact FirstName LastName   Log_Age
# 0  FT 012-345-6789  Fernando   Torres  0.510826
# 1  SG 012-345-6789    Steven  Gerrard  0.693147
# 2  LS 012-345-6789      Luis   Suarez  0.405465
# 3  MS 012-345-6789   Mohamed    Salah  0.000000

# %%
Q1 = df['Income'].quantile(0.25)
Q3 = df['Income'].quantile(0.75)
IQR = Q3 - Q1
outliers = df[(df['Income'] < (Q1 - 1.5 * IQR)) | (df['Income'] > (Q3 + 1.5 * IQR))]
outliers
# Out:
# Empty DataFrame
# Columns: [Name, Date of Birth, Age, Nationality, Income, Contact, FirstName, LastName, Log_Age]
# Index: []

# %%
# Capping outliers
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR
df['Income'] = df['Income'].clip(lower=lower_limit, upper=upper_limit)
df
# Out:
#               Name Date of Birth       Age Nationality    Income  \
# 0  Fernando Torres    1984-03-20  0.666667       SPAIN -0.626145
# 1   Steven Gerrard    1980-05-30  1.000000          UK -0.835374
# 2      Luis Suarez    1987-01-24  0.500000     URUGUAY  1.379633
# 3    Mohamed Salah    1992-06-15  0.000000       EGYPT  0.081886
#
#            Contact FirstName LastName   Log_Age
# 0  FT 012-345-6789  Fernando   Torres  0.510826
# 1  SG 012-345-6789    Steven  Gerrard  0.693147
# 2  LS 012-345-6789      Luis   Suarez  0.405465
# 3  MS 012-345-6789   Mohamed    Salah  0.000000

# %%
# Applying square root transformation to reduce right skew
df['sqrt_Income'] = df['Income'].apply(np.sqrt)
df
# Out:
#               Name Date of Birth       Age Nationality    Income  \
# 0  Fernando Torres    1984-03-20  0.666667       SPAIN -0.626145
# 1   Steven Gerrard    1980-05-30  1.000000          UK -0.835374
# 2      Luis Suarez    1987-01-24  0.500000     URUGUAY  1.379633
# 3    Mohamed Salah    1992-06-15  0.000000       EGYPT  0.081886
#
#            Contact FirstName LastName   Log_Age  sqrt_Income
# 0  FT 012-345-6789  Fernando   Torres  0.510826          NaN
# 1  SG 012-345-6789    Steven  Gerrard  0.693147          NaN
# 2  LS 012-345-6789      Luis   Suarez  0.405465     1.174578
# 3  MS 012-345-6789   Mohamed    Salah  0.000000     0.286158

# %%
# One-hot encoding
encoded_df = pd.get_dummies(df, columns=['Nationality'])
encoded_df
# Out:
#               Name Date of Birth       Age    Income          Contact  \
# 0  Fernando Torres    1984-03-20  0.666667 -0.626145  FT 012-345-6789
# 1   Steven Gerrard    1980-05-30  1.000000 -0.835374  SG 012-345-6789
# 2      Luis Suarez    1987-01-24  0.500000  1.379633  LS 012-345-6789
# 3    Mohamed Salah    1992-06-15  0.000000  0.081886  MS 012-345-6789
#
#   FirstName LastName   Log_Age  sqrt_Income  Nationality_EGYPT  \
# 0  Fernando   Torres  0.510826          NaN              False
# 1    Steven  Gerrard  0.693147          NaN              False
# 2      Luis   Suarez  0.405465     1.174578              False
# 3   Mohamed    Salah  0.000000     0.286158               True
#
#    Nationality_SPAIN  Nationality_UK  Nationality_URUGUAY
# 0               True           False                False
# 1              False            True                False
# 2              False           False                 True
# 3              False           False                False

# %%
# Extracting phone numbers
df['Phone_Number'] = df['Contact'].str.extract(r'(\d{3}-\d{3}-\d{4})')
df
# Out:
#               Name Date of Birth       Age Nationality    Income  \
# 0  Fernando Torres    1984-03-20  0.666667       SPAIN -0.626145
# 1   Steven Gerrard    1980-05-30  1.000000          UK -0.835374
# 2      Luis Suarez    1987-01-24  0.500000     URUGUAY  1.379633
# 3    Mohamed Salah    1992-06-15  0.000000       EGYPT  0.081886
#
#            Contact FirstName LastName   Log_Age  sqrt_Income  Phone_Number
# 0  FT 012-345-6789  Fernando   Torres  0.510826          NaN  012-345-6789
# 1  SG 012-345-6789    Steven  Gerrard  0.693147          NaN  012-345-6789
# 2  LS 012-345-6789      Luis   Suarez  0.405465     1.174578  012-345-6789
# 3  MS 012-345-6789   Mohamed    Salah  0.000000     0.286158  012-345-6789
