# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data():
    return pd.read_csv('data/coffee_sales.csv', parse_dates=['order_date'])
df = load_data()
df.head(3)
# Out:
#   order_date     market   region product_category            product  cost  \
# 0 2010-01-01  Wholesale  Central           Coffee           Amaretto    89
# 1 2010-01-01  Wholesale  Central           Coffee          Columbian    83
# 2 2010-01-01  Wholesale  Central           Coffee  Decaf Irish Cream    95
#
#    inventory  net_profit  sales
# 0        777          94    219
# 1        623          68    190
# 2        821         101    234

# %%
pd.crosstab(df['region'], df['product_category'])
# Out:
# product_category  Coffee  Espresso  Herbal tea  Tea
# region
# Central              384       288         336  336
# East                 168       240         216  264
# South                192       288         192    0
# West                 312       360         312  360

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    rownames=['US Region'], 
    colnames=['Product Category']
)
# Out:
# Product Category  Coffee  Espresso  Herbal tea  Tea
# US Region
# Central              384       288         336  336
# East                 168       240         216  264
# South                192       288         192    0
# West                 312       360         312  360

# %%
pd.crosstab(
    df['region'], 
    [df['product_category'], df['market']]
)
# Out:
# product_category Coffee           Espresso           Herbal tea            \
# market           Retail Wholesale   Retail Wholesale     Retail Wholesale
# region
# Central             192       192      144       144        144       192
# East                 72        96       96       144         72       144
# South               144        48      216        72        144        48
# West                240        72      288        72        240        72
#
# product_category    Tea
# market           Retail Wholesale
# region
# Central             168       168
# East                 96       168
# South                 0         0
# West                288        72

# %%
pd.crosstab(
    df['region'], 
    [df['product_category'], df['market']],
    rownames=['US Region'], 
    colnames=['Product Category', 'Market']
)
# Out:
# Product Category Coffee           Espresso           Herbal tea            \
# Market           Retail Wholesale   Retail Wholesale     Retail Wholesale
# US Region
# Central             192       192      144       144        144       192
# East                 72        96       96       144         72       144
# South               144        48      216        72        144        48
# West                240        72      288        72        240        72
#
# Product Category    Tea
# Market           Retail Wholesale
# US Region
# Central             168       168
# East                 96       168
# South                 0         0
# West                288        72

# %%
pd.crosstab(df['region'], df['product_category'], margins = True)
# Out:
# product_category  Coffee  Espresso  Herbal tea  Tea   All
# region
# Central              384       288         336  336  1344
# East                 168       240         216  264   888
# South                192       288         192    0   672
# West                 312       360         312  360  1344
# All                 1056      1176        1056  960  4248

# %%
pd.crosstab(
    df['region'], df['product_category'], 
    margins = True, 
    margins_name = 'Subtotals'
)
# Out:
# product_category  Coffee  Espresso  Herbal tea  Tea  Subtotals
# region
# Central              384       288         336  336       1344
# East                 168       240         216  264        888
# South                192       288         192    0        672
# West                 312       360         312  360       1344
# Subtotals           1056      1176        1056  960       4248

# %%
pd.crosstab(df['region'], df['product_category'], normalize = True)
# Out:
# product_category    Coffee  Espresso  Herbal tea       Tea
# region
# Central           0.090395  0.067797    0.079096  0.079096
# East              0.039548  0.056497    0.050847  0.062147
# South             0.045198  0.067797    0.045198  0.000000
# West              0.073446  0.084746    0.073446  0.084746

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    normalize = True
).style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ec27_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >product_category</th>
#       <th class="col_heading level0 col0" >Coffee</th>
#       <th class="col_heading level0 col1" >Espresso</th>
#       <th class="col_heading level0 col2" >Herbal tea</th>
#       <th class="col_heading level0 col3" >Tea</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ec27_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_9ec27_row0_col0" class="data row0 col0" >9.04%</td>
#       <td id="T_9ec27_row0_col1" class="data row0 col1" >6.78%</td>
#       <td id="T_9ec27_row0_col2" class="data row0 col2" >7.91%</td>
#       <td id="T_9ec27_row0_col3" class="data row0 col3" >7.91%</td>
#     </tr>
#     <tr>
#       <th id="T_9ec27_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_9ec27_row1_col0" class="data row1 col0" >3.95%</td>
#       <td id="T_9ec27_row1_col1" class="data row1 col1" >5.65%</td>
#       <td id="T_9ec27_row1_col2" class="data row1 col2" >5.08%</td>
#       <td id="T_9ec27_row1_col3" class="data row1 col3" >6.21%</td>
#     </tr>
#     <tr>
#       <th id="T_9ec27_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_9ec27_row2_col0" class="data row2 col0" >4.52%</td>
#       <td id="T_9ec27_row2_col1" class="data row2 col1" >6.78%</td>
#       <td id="T_9ec27_row2_col2" class="data row2 col2" >4.52%</td>
#       <td id="T_9ec27_row2_col3" class="data row2 col3" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9ec27_level0_row3" class="row_heading level0 row3" >West</th>
#       <td id="T_9ec27_row3_col0" class="data row3 col0" >7.34%</td>
#       <td id="T_9ec27_row3_col1" class="data row3 col1" >8.47%</td>
#       <td id="T_9ec27_row3_col2" class="data row3 col2" >7.34%</td>
#       <td id="T_9ec27_row3_col3" class="data row3 col3" >8.47%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    margins = True, 
    normalize = True
).style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c800a_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >product_category</th>
#       <th class="col_heading level0 col0" >Coffee</th>
#       <th class="col_heading level0 col1" >Espresso</th>
#       <th class="col_heading level0 col2" >Herbal tea</th>
#       <th class="col_heading level0 col3" >Tea</th>
#       <th class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c800a_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_c800a_row0_col0" class="data row0 col0" >9.04%</td>
#       <td id="T_c800a_row0_col1" class="data row0 col1" >6.78%</td>
#       <td id="T_c800a_row0_col2" class="data row0 col2" >7.91%</td>
#       <td id="T_c800a_row0_col3" class="data row0 col3" >7.91%</td>
#       <td id="T_c800a_row0_col4" class="data row0 col4" >31.64%</td>
#     </tr>
#     <tr>
#       <th id="T_c800a_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_c800a_row1_col0" class="data row1 col0" >3.95%</td>
#       <td id="T_c800a_row1_col1" class="data row1 col1" >5.65%</td>
#       <td id="T_c800a_row1_col2" class="data row1 col2" >5.08%</td>
#       <td id="T_c800a_row1_col3" class="data row1 col3" >6.21%</td>
#       <td id="T_c800a_row1_col4" class="data row1 col4" >20.90%</td>
#     </tr>
#     <tr>
#       <th id="T_c800a_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_c800a_row2_col0" class="data row2 col0" >4.52%</td>
#       <td id="T_c800a_row2_col1" class="data row2 col1" >6.78%</td>
#       <td id="T_c800a_row2_col2" class="data row2 col2" >4.52%</td>
#       <td id="T_c800a_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_c800a_row2_col4" class="data row2 col4" >15.82%</td>
#     </tr>
#     <tr>
#       <th id="T_c800a_level0_row3" class="row_heading level0 row3" >West</th>
#       <td id="T_c800a_row3_col0" class="data row3 col0" >7.34%</td>
#       <td id="T_c800a_row3_col1" class="data row3 col1" >8.47%</td>
#       <td id="T_c800a_row3_col2" class="data row3 col2" >7.34%</td>
#       <td id="T_c800a_row3_col3" class="data row3 col3" >8.47%</td>
#       <td id="T_c800a_row3_col4" class="data row3 col4" >31.64%</td>
#     </tr>
#     <tr>
#       <th id="T_c800a_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_c800a_row4_col0" class="data row4 col0" >24.86%</td>
#       <td id="T_c800a_row4_col1" class="data row4 col1" >27.68%</td>
#       <td id="T_c800a_row4_col2" class="data row4 col2" >24.86%</td>
#       <td id="T_c800a_row4_col3" class="data row4 col3" >22.60%</td>
#       <td id="T_c800a_row4_col4" class="data row4 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    margins = True, 
    normalize = 'columns'
).style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f6a7_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >product_category</th>
#       <th class="col_heading level0 col0" >Coffee</th>
#       <th class="col_heading level0 col1" >Espresso</th>
#       <th class="col_heading level0 col2" >Herbal tea</th>
#       <th class="col_heading level0 col3" >Tea</th>
#       <th class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f6a7_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_1f6a7_row0_col0" class="data row0 col0" >36.36%</td>
#       <td id="T_1f6a7_row0_col1" class="data row0 col1" >24.49%</td>
#       <td id="T_1f6a7_row0_col2" class="data row0 col2" >31.82%</td>
#       <td id="T_1f6a7_row0_col3" class="data row0 col3" >35.00%</td>
#       <td id="T_1f6a7_row0_col4" class="data row0 col4" >31.64%</td>
#     </tr>
#     <tr>
#       <th id="T_1f6a7_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_1f6a7_row1_col0" class="data row1 col0" >15.91%</td>
#       <td id="T_1f6a7_row1_col1" class="data row1 col1" >20.41%</td>
#       <td id="T_1f6a7_row1_col2" class="data row1 col2" >20.45%</td>
#       <td id="T_1f6a7_row1_col3" class="data row1 col3" >27.50%</td>
#       <td id="T_1f6a7_row1_col4" class="data row1 col4" >20.90%</td>
#     </tr>
#     <tr>
#       <th id="T_1f6a7_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_1f6a7_row2_col0" class="data row2 col0" >18.18%</td>
#       <td id="T_1f6a7_row2_col1" class="data row2 col1" >24.49%</td>
#       <td id="T_1f6a7_row2_col2" class="data row2 col2" >18.18%</td>
#       <td id="T_1f6a7_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_1f6a7_row2_col4" class="data row2 col4" >15.82%</td>
#     </tr>
#     <tr>
#       <th id="T_1f6a7_level0_row3" class="row_heading level0 row3" >West</th>
#       <td id="T_1f6a7_row3_col0" class="data row3 col0" >29.55%</td>
#       <td id="T_1f6a7_row3_col1" class="data row3 col1" >30.61%</td>
#       <td id="T_1f6a7_row3_col2" class="data row3 col2" >29.55%</td>
#       <td id="T_1f6a7_row3_col3" class="data row3 col3" >37.50%</td>
#       <td id="T_1f6a7_row3_col4" class="data row3 col4" >31.64%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    margins = True, 
    normalize = 'index'
).style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b22d8_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >product_category</th>
#       <th class="col_heading level0 col0" >Coffee</th>
#       <th class="col_heading level0 col1" >Espresso</th>
#       <th class="col_heading level0 col2" >Herbal tea</th>
#       <th class="col_heading level0 col3" >Tea</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b22d8_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_b22d8_row0_col0" class="data row0 col0" >28.57%</td>
#       <td id="T_b22d8_row0_col1" class="data row0 col1" >21.43%</td>
#       <td id="T_b22d8_row0_col2" class="data row0 col2" >25.00%</td>
#       <td id="T_b22d8_row0_col3" class="data row0 col3" >25.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b22d8_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_b22d8_row1_col0" class="data row1 col0" >18.92%</td>
#       <td id="T_b22d8_row1_col1" class="data row1 col1" >27.03%</td>
#       <td id="T_b22d8_row1_col2" class="data row1 col2" >24.32%</td>
#       <td id="T_b22d8_row1_col3" class="data row1 col3" >29.73%</td>
#     </tr>
#     <tr>
#       <th id="T_b22d8_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_b22d8_row2_col0" class="data row2 col0" >28.57%</td>
#       <td id="T_b22d8_row2_col1" class="data row2 col1" >42.86%</td>
#       <td id="T_b22d8_row2_col2" class="data row2 col2" >28.57%</td>
#       <td id="T_b22d8_row2_col3" class="data row2 col3" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b22d8_level0_row3" class="row_heading level0 row3" >West</th>
#       <td id="T_b22d8_row3_col0" class="data row3 col0" >23.21%</td>
#       <td id="T_b22d8_row3_col1" class="data row3 col1" >26.79%</td>
#       <td id="T_b22d8_row3_col2" class="data row3 col2" >23.21%</td>
#       <td id="T_b22d8_row3_col3" class="data row3 col3" >26.79%</td>
#     </tr>
#     <tr>
#       <th id="T_b22d8_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_b22d8_row4_col0" class="data row4 col0" >24.86%</td>
#       <td id="T_b22d8_row4_col1" class="data row4 col1" >27.68%</td>
#       <td id="T_b22d8_row4_col2" class="data row4 col2" >24.86%</td>
#       <td id="T_b22d8_row4_col3" class="data row4 col3" >22.60%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    values = df['cost'],
    aggfunc = 'mean'
)
# Out:
# product_category      Coffee   Espresso  Herbal tea         Tea
# region
# Central            74.390625  89.666667   87.065476   87.690476
# East              110.976190  95.600000  101.240741   46.962121
# South              78.916667  62.305556   56.270833         NaN
# West               90.814103  84.133333   98.987179  100.844444

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    values = df['cost'],
    aggfunc = 'mean'
).round(2)
# Out:
# product_category  Coffee  Espresso  Herbal tea     Tea
# region
# Central            74.39     89.67       87.07   87.69
# East              110.98     95.60      101.24   46.96
# South              78.92     62.31       56.27     NaN
# West               90.81     84.13       98.99  100.84

# %%
pd.crosstab(
    df['region'], 
    df['product_category'], 
    values = df['cost'],
    aggfunc = 'mean',
).fillna(0)
# Out:
# product_category      Coffee   Espresso  Herbal tea         Tea
# region
# Central            74.390625  89.666667   87.065476   87.690476
# East              110.976190  95.600000  101.240741   46.962121
# South              78.916667  62.305556   56.270833    0.000000
# West               90.814103  84.133333   98.987179  100.844444

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    pd.crosstab(
        df['region'], 
        [df['product_category'], df['market']],
        rownames=['US Region'], 
        colnames=['Product Category', 'Market'],
        values = df['cost'],
        aggfunc = 'mean'
    ), 
    annot = True
)
plt.show()
