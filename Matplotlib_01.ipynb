# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.hist(df['sepal_width']);

# %%
plt.hist(df['sepal_width'])
plt.hist(df['petal_width']);

# %%
# Make 14 rows of fake data.
a = pd.util.testing.makeDataFrame().reset_index().drop(columns='index')
b = pd.util.testing.makeDataFrame().reset_index().drop(columns='index').rename(columns={'A':'E', 'B':'F', 'C':'G', 'D':'H'}) 
c = pd.util.testing.makeDataFrame().reset_index().drop(columns='index').rename(columns={'A':'I', 'B':'J', 'C':'K', 'D':'L'}) 
d = pd.util.testing.makeDataFrame().reset_index().drop(columns='index').rename(columns={'A':'M', 'B':'N', 'C':'O', 'D':'P'})
df = pd.concat([a, b, c, d], axis=1).drop(columns=['O', 'P'])
df.head(7)
# Out:
#           A         B         C         D         E         F         G  \
# 0 -0.682895  0.940542 -1.617482  0.594958 -2.341149  1.441102 -1.336739
# 1  2.924213  0.045727  1.418255 -0.274839  1.720787  1.176553 -0.294874
# 2  0.208156 -0.763505  1.502584 -0.031254 -0.256201  0.878196  0.041091
# 3 -1.143908 -0.931288 -0.645032 -1.825316 -0.748159 -1.280094 -0.259878
# 4 -1.309470 -0.759899 -0.614009  0.667015 -1.363006 -0.307760  0.710189
# 5  1.133232  1.013687  1.123944 -0.524439  1.539408  0.877336 -0.607592
# 6  1.420979 -0.700341  1.765864 -0.474462 -0.138763  0.308070  0.842211
#
#           H         I         J         K         L         M         N
# 0  0.662562 -0.833339 -2.316285 -1.032206 -0.498476 -0.121629  0.017698
# 1 -1.040135 -0.527159 -1.242456 -0.398066 -0.523056  0.934361  0.001140
# 2 -1.006771  0.634267 -0.446020 -0.697361 -0.537347  0.026575  0.285507
# 3  0.321646 -0.953573 -1.610357  0.225685  0.122517 -0.603000  1.397680
# 4  0.618027  0.395392  1.551011  0.911731 -0.975473 -0.588617  1.675399
# 5  0.749049 -1.704431  0.042225 -1.066338 -2.555761  1.434182  0.527938
# 6 -0.397909 -0.580266  0.907158  0.401462  0.742095  1.880239  0.791957

# %%
plt.figure()

# %%
# figsize = (width, height)
plt.figure(figsize = (17,12))

# %%
fig = plt.figure(figsize = (17, 12))
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig = plt.figure(figsize=(20, 12))
# add_subplot(nrows, ncolumns, position)
fig.add_subplot(3, 5, 1) #3 rows, 5 columns, position 1
fig.add_subplot(3, 5, 3); #3 rows, 5 columns, position 3

# %%
fig = plt.figure(figsize=(20, 12))
ax0 = fig.add_subplot(3, 5, 1)
ax1 = fig.add_subplot(3, 5, 2)
foo = fig.add_subplot(3, 5, 3)
bar = fig.add_subplot(3, 5, 5);

# %%
type(ax0), type(foo)
# Out:
# (matplotlib.axes._subplots.AxesSubplot, matplotlib.axes._subplots.AxesSubplot)

# %%
fig = plt.figure(figsize=(20, 12))
# Add titles
ax0 = fig.add_subplot(3, 5, 1)
ax1 = fig.add_subplot(3, 5, 2)
foo = fig.add_subplot(3, 5, 3)
foo.set(title='foo')
bar = fig.add_subplot(3, 5, 5).set(title='bar');

# %%
fig = plt.figure(figsize=(20, 12))
# Generate 10 plots in a grid with 3 rows, 5 columns
for i in range(1,11):
    ax = fig.add_subplot(3, 5, i)
    ax.set(title=f'graph {i}')
    
fig.suptitle('ten subplots');

# %%
fig = plt.figure(figsize=(20, 12))
# Make some weird subplots
# .add_subplot(nrows, ncolumns, position)
ax0 = fig.add_subplot(7, 4, 1)
ax1 = fig.add_subplot(4, 7, 3)
ax2 = fig.add_subplot(6, 5, 6)
ax3 = fig.add_subplot(12, 12, 40)

# %%
plt.hist(df['A']);

# %%
fig = plt.figure(figsize=(20, 12))
ax0 = fig.add_subplot(3, 4, 1)
ax0.hist(df['B'])
ax1 = fig.add_subplot(3, 4, 2).hist(df['C']);
#ax2 =
#ax3 =

# %%
fig = plt.figure(figsize=(20, 12))
# Generate 15 plots in a grid with 3 rows, 5columns
for i, col in enumerate(df.columns):
    ax = fig.add_subplot(3, 5, i+1) 
    ax.hist(df[col])
plt.show()

# %%
fig, axs = plt.subplots(
    nrows=3, ncols=5, figsize=(20, 12))

# %%
# alternative names
# (don't do this tho)
foo, bar = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))

# %%
type(axs)
# Out:
# numpy.ndarray

# %%
axs
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
fig, axs = plt.subplots(nrows=3, ncols=5, figsize=(20, 12))
axs[0, 0].hist(df['A'])
axs[1, 2].hist(df['B'])
axs[2, 1].hist(df['C'])
fig.show()

# %%
fig, axes = plt.subplots(3, 5, figsize=(20, 12))
for col, ax in zip(df.columns, axes.flat):
    print(col, type(df[col]), type(ax))
# Out:
# A <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# B <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# C <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# D <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# E <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# F <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# G <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# H <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# I <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# J <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# K <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# L <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# M <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>
# N <class 'pandas.core.series.Series'> <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig, axes = plt.subplots(3, 5, figsize=(20, 12), sharey=True)
for col, ax in zip(df.columns, axes.flat):
    df[col].hist(ax=ax)
    ax.set_title(col)
    
# delete the leftover axes
for ax in axes.flat[df.columns.size:]:
     ax.set_axis_off()
