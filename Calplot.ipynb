# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import seaborn as sns
import calplot
import calendar
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/dailyPowerGeneration.csv')
df['Date'] = pd.to_datetime(df.Date, yearfirst=True)
df.set_index('Date', inplace=True)
df.head()
# Out:
#             index        Region Thermal Generation Actual (in MU)  \
# Date
# 2017-09-01      0      Northern                            624.23
# 2017-09-01      1       Western                          1,106.89
# 2017-09-01      2      Southern                            576.66
# 2017-09-01      3       Eastern                            441.02
# 2017-09-01      4  NorthEastern                             29.11
#
#            Thermal Generation Estimated (in MU)  \
# Date
# 2017-09-01                               484.21
# 2017-09-01                             1,024.33
# 2017-09-01                               578.55
# 2017-09-01                               429.39
# 2017-09-01                                15.91
#
#             Nuclear Generation Actual (in MU)  \
# Date
# 2017-09-01                              30.36
# 2017-09-01                              25.17
# 2017-09-01                              62.73
# 2017-09-01                                NaN
# 2017-09-01                                NaN
#
#             Nuclear Generation Estimated (in MU)  \
# Date
# 2017-09-01                                 35.57
# 2017-09-01                                  3.81
# 2017-09-01                                 49.80
# 2017-09-01                                   NaN
# 2017-09-01                                   NaN
#
#             Hydro Generation Actual (in MU)  \
# Date
# 2017-09-01                           273.27
# 2017-09-01                            72.00
# 2017-09-01                           111.57
# 2017-09-01                            85.94
# 2017-09-01                            24.64
#
#             Hydro Generation Estimated (in MU)
# Date
# 2017-09-01                              320.81
# 2017-09-01                               21.53
# 2017-09-01                               64.78
# 2017-09-01                               69.36
# 2017-09-01                               21.21

# %%
col = 'Hydro Generation Actual (in MU)'
calplot.calplot(df[col], how='sum')
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# (<Figure size 900x489.6 with 5 Axes>,
#  array([<AxesSubplot:ylabel='2017'>, <AxesSubplot:ylabel='2018'>,
#         <AxesSubplot:ylabel='2019'>, <AxesSubplot:ylabel='2020'>],
#        dtype=object))

# %%
col = 'Hydro Generation Actual (in MU)'
title = 'Daily Power Generation in India\nHydro Generation Actual (in MU)\n'
cmap = sns.dark_palette('#69d', as_cmap=True)
calplot.calplot(df[col], how='sum', 
                suptitle=title, cmap=cmap,
                linecolor='w', linewidth=2, 
                fillcolor='w', edgecolor='black')
plt.show()

# %%
col = 'Hydro Generation Actual (in MU)'
title = 'Daily Power Generation in India\nHydro Generation Actual (in MU)\n'
facecolor = '#414141'
font_path = 'data/fonts/NotoSans-Regular.ttf'
fontproperties = fm.FontProperties(fname=font_path, size=22)
yearlabel_kws = dict(fontproperties=fontproperties
                     ,color='#5698B3'
                     ,ha='center')
suptitle_kws = dict(fontproperties=fontproperties
                     ,color='#6CBCDC'
                     ,ha='left'
                     ,y=1.125
                     ,x=-0.025)
fig_kws = dict(facecolor=facecolor)
subplot_kws = dict(facecolor=facecolor)
cmap = sns.dark_palette('#69d', as_cmap=True)
calplot.calplot(df[col], how='sum', 
                suptitle=title, suptitle_kws=suptitle_kws,
                yearlabel_kws=yearlabel_kws, fig_kws=fig_kws,
                subplot_kws = subplot_kws, linecolor=facecolor,
                edgecolor='black', fillcolor=facecolor, 
                linewidth=2, cmap=cmap)
plt.show()

# %%
col = 'Hydro Generation Actual (in MU)'
title = 'Daily Power Generation in India\nHydro Generation Actual (in MU)\n'
facecolor = '#414141'
font_path = 'data/fonts/NotoSans-Regular.ttf'
fontproperties = fm.FontProperties(fname=font_path, size=22)
yearlabel_kws = dict(fontproperties=fontproperties
                     ,color='#5698B3'
                     ,ha='center')
suptitle_kws = dict(fontproperties=fontproperties
                     ,color='#6CBCDC'
                     ,ha='left'
                     ,y=1.125
                     ,x=-0.025)
fig_kws = dict(facecolor=facecolor)
subplot_kws = dict(facecolor=facecolor)
cmap = sns.dark_palette('#69d', as_cmap=True) 
fig, axes = calplot.calplot(df[col],
                            how='sum',
                            suptitle=title,
                            suptitle_kws=suptitle_kws,
                            yearlabel_kws=yearlabel_kws,
                            fig_kws=fig_kws,
                            subplot_kws = subplot_kws,
                            linecolor=facecolor, 
                            edgecolor='black',
                            fillcolor=facecolor, 
                            linewidth=2, cmap=cmap)
for ax in axes:
    ax.set_xticklabels(calendar.month_abbr[1:], color='w')
    ax.set_yticklabels(calendar.day_abbr[:], color='w')
plt.show()
